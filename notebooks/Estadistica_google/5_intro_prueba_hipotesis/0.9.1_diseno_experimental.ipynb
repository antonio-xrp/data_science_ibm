# %% [markdown]
# Diseño experimentalEstado
#
# A lo largo de este curso, hemos analizado cómo los profesionales de datos utilizan las pruebas de hipótesis para determinar si los resultados de un experimento son estadísticamente significativos. En escenarios anteriores, analizamos los resultados de experimentos como ensayos clínicos y Pruebas A/B. Por ejemplo, imaginamos un ensayo clínico que prueba la eficacia de un nuevo medicamento y una prueba A/B que examina cómo cambiar el diseño de una página web afecta al tiempo medio que los clientes pasan en la página.
#
# Los profesionales de los datos suelen trabajar con datos experimentales recogidos previamente por otros investigadores. Sin embargo, los datos adecuados para un proyecto concreto pueden no estar siempre disponibles o accesibles. En este caso, los profesionales de los datos pueden diseñar sus propios experimentos y recopilar sus propios datos.
#
# En esta lectura, analizaremos cómo los profesionales de datos diseñan experimentos para recopilar datos, probar hipótesis y descubrir relaciones entre variables. Aprenderá más sobre los conceptos y procedimientos básicos del diseño experimental.
#
# ### Contexto: Diseño experimental
#
# El diseñoexperimental se refiere a la planificación de un experimento con el fin de recopilar datos para responder a su pregunta de investigación.
#
# Los investigadores realizan experimentos en muchos campos: medicina, física, psicología, fabricación, marketing y otros. El propósito típico de un experimento es descubrir una relación causa-efecto entre variables. Por ejemplo, un profesional de los datos puede diseñar un experimento para descubrir si:
#
# - Un nuevo medicamento acelera el tiempo de recuperación
#
# - Un nuevo diseño de página web aumenta las ventas de productos
#
# - Un nuevo fertilizante aumenta el crecimiento de los cultivos
#
# - Un nuevo programa de entrenamiento mejora el rendimiento deportivo
#
# Es importante comprender el diseño experimental porque afecta a la calidad de los datos y a la validez de las conclusiones que se extraen a partir de los resultados. Un diseño deficiente puede dar lugar a resultados no válidos, que pueden resultar costosos para las empresas y los consumidores. Basándose en los resultados de un experimento defectuoso, una empresa puede pasarse años desarrollando un medicamento que es ineficaz o hacer grandes inversiones en un proceso de fabricación que es ineficiente. Un experimento bien diseñado le proporcionará datos fiables que le ayudarán a responder a su pregunta de investigación.
#
# Puede explorar un ejemplo para comprender mejor el diseño experimental.
#
# ### Ejemplo: Ensayo clínico
#
# Imagina que eres un profesional de los datos que trabaja para una empresa farmacéutica. La empresa inventa un nuevo medicamento para tratar el resfriado común. El jefe de tu equipo te pide que diseñes un experimento para comprobar la eficacia del medicamento. Quieres averiguar si la toma del medicamento acelera el tiempo de recuperación.
#
# ![image.png](attachment:image.png)
#
# En el diseño de un experimento hay al menos tres pasos clave:
#
# 1. Definir las variables
#
# 2. Formular la hipótesis
#
# 3. Asignar los sujetos de la prueba a los grupos de tratamiento y control.
#
# **Nota:** Estos son los pasos básicos que se aplican a los experimentos controlados (más información a continuación). El diseño experimental es un tema complejo, y una discusión más detallada queda fuera del alcance de este curso.
#
# A continuación, examine cada paso con más detalle utilizando nuestro ejemplo.
#
# ### Paso 1: Defina sus variables
#
# Los profesionales de los datos suelen empezar por definir las variables independientes y dependientes de su experimento. Esto ayuda a aclarar la relación entre las variables.
#
# - La variable independiente se refiere a la causa que le interesa investigar. Un investigador cambia o controla la variable independiente para determinar cómo afecta a la variable dependiente. "Independiente" significa que no está influida por otras variables del experimento.
#
# - La variable depend iente se refiere al efecto que le interesa medir. "Dependiente" significa que su valor está influido por la variable independiente.
#
# En su ensayo clínico, quiere averiguar cómo afecta el medicamento al tiempo de recuperación. Por lo tanto:
#
# - Su variable independiente es el medicamento, la causa que desea investigar.
#
# - Su variable dependiente es el tiempo de recuperación, el efecto que desea medir.
#
# En un experimento más complejo, puede probar el efecto de diferentes medicamentos sobre el tiempo de recuperación o diferentes dosis del mismo medicamento. En cada caso, se manipula la variable independiente (medicamento) para medir su efecto sobre la variable dependiente (tiempo de recuperación).
#
# **Nota:** Más adelante en este programa de certificación, cuando hablemos del análisis de regresión, tendrá la oportunidad de aprender sobre las variables independientes y dependientes con más detalle.
#
# ### Paso 2: Formule su hipótesis
#
# El siguiente paso es formular una hipótesis. La hipótesis establece la relación entre las variables independientes y dependientes y predice el resultado del experimento. Antes ha aprendido que los profesionales de los datos formulan hipótesis nulas y alternativas cuando realizan investigaciones que implican pruebas estadísticas. Recuerde que la hipótesis nula suele suponer que no hay ningún efecto en la población y que la hipótesis alternativa supone lo contrario. Para su ensayo clínico:
#
# - Su hipótesis nula (H0) es que el medicamento no tiene ningún efecto.
#
# - La hipótesis alternativa (Ha) es que el medicamento es eficaz.
#
# #### Paso 3: Asignación de los sujetos de ensayo a los grupos de tratamiento y control
#
# **Grupos de tratamiento y de control**
#
# Los experimentos como los ensayos clínicos y las Pruebas A/B son experimentos controlados. En un experimento controlado, los sujetos de ensayo se asignan a un grupo de tratamiento y a un grupo de control. El tratamiento es el nuevo cambio que se prueba en el experimento. El grupo de tratamiento está expuesto al tratamiento. El grupo de control no está expuesto al tratamiento. La diferencia en los valores métricos entre los dos grupos mide el efecto del tratamiento en los sujetos de ensayo.
#
# En el ensayo clínico, el tratamiento es el medicamento que se administra a los sujetos del grupo de tratamiento. Los sujetos del grupo de control no reciben el medicamento. Imagine que sus resultados muestran que el tiempo medio de recuperación es menor en el grupo de tratamiento (6,2 días) que en el grupo de control (7,5 días). La diferencia entre los dos grupos, 7,5 - 6,2 = 1,3 días, mide el impacto del tratamiento. En otras palabras, el medicamento disminuye el tiempo medio de recuperación en 1,3 días.
#
# Nota: Después de que un profesional de los datos diseñe y ejecute su experimento, utiliza pruebas estadísticas para analizar los resultados. Como siguiente paso, podría realizar una prueba t de dos muestras para determinar si la diferencia observada en el tiempo de recuperación es estadísticamente significativa o se debe al azar.
#
# Lo ideal es que la exposición al tratamiento sea la única diferencia significativa entre los dos grupos. Este diseño permite a los investigadores controlar otros factores que podrían influir en los resultados de la prueba y extraer conclusiones causales sobre el efecto del tratamiento.
#
# Por ejemplo, imagine que los sujetos del grupo de tratamiento tienen una dieta mucho más sana que los sujetos del grupo de control. Cualquier disminución observada en el tiempo de recuperación del grupo de tratamiento podría deberse a su dieta más sana, y no al medicamento. En este caso, no se puede afirmar con seguridad que el medicamento por sí solo sea la causa de un tiempo de recuperación más rápido.
#
# **Aleatorización**
#
# Normalmente, los profesionales de datos asignan aleatoriamente los sujetos de prueba a los grupos de tratamiento y control. La aleatorización ayuda a controlar el efecto de otros factores en el resultado de un experimento. Dos métodos habituales para asignar sujetos a los grupos de tratamiento y control son el diseño completamente aleatorizado y el diseño de bloques aleatorizados.
#
# En un diseño completamente aleatorizado, los sujetos de ensayo se asignan a los grupos de tratamiento y control mediante un proceso aleatorio. Por ejemplo, en un ensayo clínico, se puede utilizar un programa informático para etiquetar a cada sujeto con un número y, a continuación, seleccionar aleatoriamente números para cada grupo.
#
# A veces, sin embargo, un diseño completamente aleatorizado puede no ser el enfoque más eficaz. Al diseñar un experimento, los profesionales de los datos deben tener en cuenta los factores perturbadores. Se trata de factores que pueden afectar al resultado de un experimento, pero que no son de interés primordial para el investigador.
#
# Los investigadores pueden utilizar un diseño de bloques aleatorizados para minimizar el impacto de los factores perturbadores conocidos. El bloqueo consiste en organizar a los sujetos de la prueba en grupos, o bloques, similares entre sí. En un diseño de bloques, primero se dividen los sujetos en bloques y luego se asignan aleatoriamente los sujetos de cada bloque a los grupos de tratamiento y control.
#
# Por ejemplo, supongamos que sabemos que la edad es un factor importante en el tiempo de recuperación de un resfriado común. En concreto, sabe que las personas menores de 35 años tienden a recuperarse antes que las mayores. En este escenario, la edad es un factor molesto porque podría afectar a los resultados de su experimento. Por ejemplo, en un ensayo clínico con un diseño completamente aleatorizado y un tamaño de muestra más pequeño, podría obtener al azar una gran proporción de jóvenes en el grupo de tratamiento. Esto hará más difícil determinar si cualquier disminución observada en el tiempo de recuperación se debe al tratamiento (medicamento) o al factor perturbador (edad).
#
# En este caso, bloquear el factor edad es una forma más eficaz de diseñar el experimento. En primer lugar, se dividen los sujetos de la prueba en bloques en función de la edad, como 21-35, 36-50 y 51-65. A continuación, se asignan aleatoriamente los sujetos de la prueba a los grupos de edad de 21-35, 36-50 y 51-65. A continuación, asigne aleatoriamente los sujetos de cada bloque a los grupos de tratamiento y control. De este modo, si hay una diferencia significativa en el tiempo de recuperación dentro de un bloque específico, puede estar más seguro de que este resultado se debe al tratamiento (medicamento) y no al factor perturbador (edad).
#
# ### Puntos clave
#
# Los profesionales de los datos utilizan el diseño experimental para planificar experimentos y recopilar datos que les ayuden a responder a sus preguntas de investigación. El diseño de un experimento afecta a la calidad de sus datos y a la validez de sus conclusiones. Tanto si diseña su propio experimento como si utiliza datos recopilados por otros, es importante que comprenda los principios básicos del diseño experimental. Estos conocimientos le ayudarán a analizar los datos de experimentos como ensayos clínicos, Pruebas A/B, etc.
