# %% [markdown]
# ### Statistics
#
# La estadística es el estudio de la recopilación, el análisis y la interpretación de datos. Las estadísticas, a menudo abreviadas como estadísticas, proporcionan a los profesionales de datos herramientas y métodos eficaces para transformar los datos en conocimiento útil.
#
# ![image.png](attachment:image.png)
#
# Basándose en una pequeña muestra de los datos disponibles, pueden hacer predicciones informadas sobre eventos inciertos y hacer estimaciones precisas sobre valores desconocidos.
#
# Por ejemplo, los profesionales de datos utilizan las estadísticas para predecir los ingresos por ventas futuros, el éxito de una nueva campaña publicitaria, la tasa de rendimiento de una inversión financiera o la cantidad de descargas de una nueva aplicación.
#
# ![image-2.png](attachment:image-2.png)
#
# Los conocimientos obtenidos del análisis estadístico ayudan a los líderes empresariales a tomar decisiones, resolver problemas complejos y mejorar el rendimiento de los productos y servicios.
#
# Econometría, una rama de la economía que utiliza las estadísticas para analizar los problemas económicos.
#
# ![image-3.png](attachment:image-3.png)
#
#
# - estadísticas descriptivas e inferenciales. Descubrirá cómo las estadísticas descriptivas, como la media, la mediana y la desviación estándar, le ayudan a resumir rápidamente y comprender mejor sus datos.
#
# - estadísticas inferenciales para sacar conclusiones y hacer predicciones sobre los datos.
# - exploraremos la probabilidad y descubriremos formas útiles de medir la incertidumbre.Analizaremos las reglas básicas de la probabilidad y cómo interpretar los diferentes tipos de distribuciones de probabilidad, como las distribuciones normal, binomial y de Poisson.
#
# - muestreo. Analizaremos qué hace que una muestra sea buena, las ventajas y desventajas de los diferentes métodos de muestreo y cómo trabajar con las distribuciones de muestreo.
#
# - intervalos de confianza que describen la incertidumbre en una estimación. Aprenderás a construir diferentes tipos de intervalos de confianza e interpretar su significado.
#
# - pruebas de hipótesis para comparar y evaluar afirmaciones contrapuestas sobre sus datos. Repasaremos los pasos para aplicar diferentes pruebas a conjuntos de datos específicos y demostraremos cómo interpretar los resultados de las pruebas.
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ---
# ---

# %% [markdown]
# - Exploraremos un ejemplo de cómo los profesionales de datos utilizan métodos estadísticos para realizar una prueba A/B.
# - Luego analizaremos los dos tipos principales de estadísticas, descriptivas e inferenciales.
#
# - Los profesionales de datos utilizan estadísticas descriptivas para explorar y resumir los datos.
# - Utilizan estadísticas inferenciales para sacar conclusiones y hacer predicciones sobre los datos.
#
# ![image.png](attachment:image.png)
#
#
# ### Descriptive Statics
# - A continuación, analizaremos tres tipos diferentes de estadísticas descriptivas y cómo pueden ayudarlo a comprender mejor los diferentes aspectos de los datos.
#
# - Las medidas de tendencia central, como la media, permiten describir el centro de un conjunto de datos.
#
# - Medidas de dispersión como la desviación estándar. Le permiten describir la dispersión de las medidas de posición de los datos.
#
# -como los percentiles, y le ayudan a determinar la posición relativa de los valores en el conjunto de datos.
#
# ![image-2.png](attachment:image-2.png)
#
#
# Finalmente, aprenderá a usar Python para calcular estadísticas descriptivas y resumir un conjunto de datos. Cuando estés listo, únete a mí en el siguiente vídeo.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### El papel de la estadística en la ciencia de datos.
#
# Hoy en día, los seres humanos generan y recopilan más datos que nunca. Cada vez que enviamos un mensaje de texto, hacemos una compra en línea o publicamos una foto en las redes sociales, generamos nuevos datos. A medida que crece la cantidad de datos, también lo hace la necesidad de analizarlos e interpretarlos. Esta es una de las principales razones por las que las estadísticas y el trabajo basado en datos son tan importantes. y el campo del análisis de datos crece casi tan rápido como los propios datos.
#
#
#
# ### Los profesionales de datos utilizan las estadísticas para analizar datos
#
# En los negocios, la medicina, la ciencia, la ingeniería, el gobierno y más.
#
#
#
# ### Los profesionales de datos utilizan los poderosos métodos estadísticos para
#
# - identificar patrones y relaciones significativos en los datos,
# - analizar y cuantificar la incertidumbre,
# - generar información a partir de los datos,
# - hacer predicciones informadas sobre el futuro y resolver problemas complejos.
#
# ![image.png](attachment:image.png)
#
#
# Incluso si nunca has estudiado estadística, es probable que utilices estadísticas a diario.
#
# - Por ejemplo, puedes empezar el día conectándote a Internet y comprobando el clima, donde te enterarás de que el pronóstico es de un 70 por ciento de probabilidades de lluvia o un 50 por ciento de probabilidades de nieve.
#
# - Quizás visites un sitio web de deportes para conocer el promedio de bateo de tu jugador de cricket favorito o el promedio de puntuación de tu jugador de baloncesto favorito.
# - En una aplicación de noticias, es posible que te encuentres con una encuesta electoral que indique un margen de error del tres por ciento y que indique que se utilizó una encuesta en línea para recopilar los datos.
# - O tal vez usted es padre y, cuando lleva a su hijo al chequeo anual, se entera de que su hijo se encuentra en un percentil determinado de estatura y peso. Cuando pides más información, el médico te muestra la estatura y el peso promedio de todos los niños de la misma edad.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Statistical conceps
#
# Estos escenarios incluyen conceptos estadísticos sobre los que aprenderá más en este curso.
# -  El informe meteorológico se basa en la probabilidad o la probabilidad de un evento.
# -  Las estadísticas deportivas expresan el valor promedio.
# - La encuesta electoral muestra un margen de error.
# - El médico utiliza el concepto de percentil y mediana.
#
# Todas estas estadísticas te brindan conocimientos útiles que puedes aplicar a tu propia vida. Los profesionales de datos utilizan el mismo concepto en su trabajo.
#
# ![image-3.png](attachment:image-3.png)
#
# ### A data professional might use probability to
#
#
# Por ejemplo:
# - un profesional de datos puede usar la probabilidad para predecir la tasa futura de rendimiento de una inversión.
# - Pueden estimar el promedio anual de ingresos por ventas de una empresa,
# -  calcular el margen de error para cuantificar la incertidumbre de una encuesta de satisfacción de los empleados
# - usar percentiles para clasificar los precios medios de las viviendas en diferentes ciudades.
#
# ![image-4.png](attachment:image-4.png)
#
#
# En el trabajo, los profesionales de datos utilizan las estadísticas para transformar los datos en información que ayude a las partes interesadas a tomar decisiones. La estadística es la base del análisis de datos y es la base de los métodos de análisis más avanzados que utilizan los profesionales de datos. Todo comienza con los conceptos fundamentales que exploramos en este curso.
#
# Considera el papel que desempeña la gramática en tus conversaciones; por ejemplo, cuando chateas con amigos o compañeros de trabajo, es probable que no estés pensando en conceptos gramaticales como las partes del discurso. Si estás conversando, entonces ya sabes cómo usar sustantivos, verbos y adjetivos.
#
# El conocimiento de la gramática básica permite utilizar el lenguaje en primer lugar. Por eso es tan fundamental. De manera similar, el conocimiento compartido de las estadísticas básicas permite a los profesionales de datos utilizar un lenguaje común.
#
# Con el tiempo, aprender lo básico te permitirá unirte a la conversación sobre temas más avanzados.
#
# ### Methods
# - las pruebas de hipótesis,
# - la clasificación,
# - la regresión
# - el análisis de series temporales.
#
# ![image-5.png](attachment:image-5.png)
