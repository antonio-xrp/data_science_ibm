# %% [markdown]
# ### Medidas de tendencia central
#
# - Cada vez que exploro un nuevo conjunto de datos, siento una sensación de emoción,  es como explorar una ciudad por primera vez. Cuando visito una ciudad nueva, suelo empezar mi viaje en el centro de la ciudad. De esta manera, puedo calcular la distancia entre el centro y los límites de la ciudad o hasta un monumento famoso que quiero visitar. Saber dónde estoy en relación con el centro me ayuda a orientarme.
#
# - Lo mismo ocurre cuando quiero obtener información sobre un conjunto de datos nuevo.
#
#     - Primero, quiero saber el centro de mi conjunto de datos, luego quiero saber qué tan dispersos están los otros valores desde el centro.
#
# - Medir el centro y la extensión del conjunto de datos me ayuda a entender rápidamente su estructura general y a decidir qué partes quiero explorar con más detalle.
#
#
# > Las medidas de tendencia central son valores que representan el centro de un conjunto de datos.
#
# > Las medidas de dispersión son valores que representan la dispersión de un conjunto de datos.
#
#
# ### Measures of central tendency
#
# - La media
# - La mediana
# - La moda.
#
#
# ### Media.
#
# - La media es el valor promedio del conjunto de datos.
#
# Para calcular la media, debes sumar todos los valores de tu conjunto de datos y dividirlos por el número total de valores.
#
# ![image.png](attachment:image.png)
#
# - Por ejemplo, supongamos que tiene el siguiente conjunto de valores: 10, 8, 5, 70. Para encontrar la media, suma todos los valores para un total de 100, luego divide por 5, el número total de valores.  El valor medio o promedio es 20.
#
# ### Mediana
#
# - La mediana es el valor medio de un conjunto de datos. Esto significa que la mitad de los valores del conjunto de datos son mayores que la mediana y la otra mitad son más pequeños.
#
# - Puede encontrar la mediana organizando todos los valores del conjunto de datos de menor a mayor. Si organizas tus cinco valores de esta manera, obtienes 5, 7, 8, 10, 70. La mediana o el valor medio es ocho.
#
# - Si son un número par de valores en su conjunto de datos, la mediana es el promedio de los dos valores intermedios. Supongamos que añades otro valor, 4, a tu conjunto. Ahora, los dos valores medios son siete y ocho. La mediana es su promedio, 7,5.
#
# - Puede observar que la media, 20, es mucho mayor que la mediana, 8. Esto se debe a que hay un valor extremo, 70, que aumenta el promedio general. Este valor se conoce como **valor atípico**.
#
#
# > Recuerde que un valor atípico es un valor que difiere mucho del resto de los datos como medidas de tendencia central.
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# - La media y la mediana funcionan mejor para diferentes tipos de datos.
#
# ###  When To use median or mean
#
#
# - Si hay valores atípicos en el conjunto de datos, la mediana suele ser una mejor medida del centro.
#
# - Si no hay outliers, la media suele funcionar bien.
#
# ![image-3.png](attachment:image-3.png)
#
# Por ejemplo, imagine que quiere comprar una casa en un vecindario específico. Recorres diez viviendas de la zona para hacerte una idea del precio medio. Las primeras nueve viviendas tienen un precio de 100.000 dólares.
#
# La décima vivienda tiene un precio de un millón de dólares. Este es un valor atípico que hace subir el promedio. Si suma todos los precios de las viviendas y divide entre 10, encontrará que el precio medio o promedio es de 190,000 dólares.
#
# La media no le da una buena medida del valor típico de una casa en este vecindario. De hecho, solo una casa de cada diez cuesta más de 100.000 dólares.
#
# El precio medio de una vivienda es de 100.000 dólares. La mediana te da una idea mucho mejor del valor típico de una vivienda en este vecindario. El hecho de que utilices la media o la mediana depende del conjunto de datos específico con el que estés trabajando y de la información que quieras obtener de tus datos.
#
# ![image-4.png](attachment:image-4.png)
#
# ### Moda
#
# - La moda es el valor que aparece con más frecuencia en el conjunto de datos.
#
# - Un conjunto de datos no puede tener ninguna moda, una moda o más de una moda.
#
# Por ejemplo, el conjunto de números: uno, dos, tres, cuatro, cinco, no tiene moda porque no hay repeticiones de valores.
#
# En el conjunto uno, tres, cinco, siete, el modo es tres porque tres es el único valor que aparece más de una vez.
#
# El conjunto uno, dos, cuatro, cuatro tiene dos modos, dos y cuatro.
#
# ![image-5.png](attachment:image-5.png)
#
# > La moda es útil cuando se trabaja con datos categóricos porque muestra claramente qué categoría aparece con más frecuencia.
#
#
# - Supongamos que una empresa minorista en línea realiza una encuesta. Los clientes califican su experiencia como mala, mediocre, buena o excelente. Un gráfico de barras resume los resultados. La barra más alta se refiere a la mala calificación. Este es el valor o moda que aparece con más frecuencia.
#
# La moda proporciona a la empresa comentarios claros sobre la satisfacción del cliente.
#
# ![image-6.png](attachment:image-6.png)
#
# - En resumen, la media, la mediana y la moda miden el centro de un conjunto de datos de diferentes maneras.
# - La media encuentra el valor promedio.
# - La mediana encuentra el valor medio
# - La moda encuentra el valor que aparece con más frecuencia.
#
#
# Conocer el centro de su conjunto de datos le ayuda a comprender rápidamente su estructura básica y a determinar los próximos pasos del análisis. Del mismo modo que conocer el centro de la ciudad te ayuda a orientarte en un nuevo entorno.
