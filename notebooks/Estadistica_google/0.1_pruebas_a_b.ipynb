# %% [markdown]
# ### Pruebas A/B
#
# Las empresas utilizan las Pruebas A/B para evaluar todo , desde el diseño de sitios web hasta las aplicaciones móviles, los anuncios en línea y los correos electrónicos de marketing.
#
# Las Pruebas A/B son una forma de comparar dos versiones de algo para averiguar qué versión funciona mejor.
#
# ![image.png](attachment:image.png)
#
# Las Pruebas A/B se han hecho populares porque funcionan bien para muchas aplicaciones en línea.
#
# Por ejemplo:
# - las empresas suelen utilizar las Pruebas A/B para crear dos versiones de una página web y averiguar cuál recibe más clics, compras o suscripciones. Incluso pequeños cambios en una página web, como cambiar el color, el tamaño o la ubicación de un botón, pueden aumentar las ganancias financieras.
#
# - Las pruebas A/B ayudan a los líderes empresariales a optimizar el rendimiento del producto y mejorar la experiencia del cliente.
#
#
# - Otra forma en que las empresas utilizan las Pruebas A/B es para los correos electrónicos de marketing. Puedes enviar dos versiones de un correo electrónico a tu lista de clientes para averiguar qué versión genera más ventas, o puedes probar dos versiones de un anuncio en línea para descubrir en cuál hacen clic los visitantes con más frecuencia.
#
# ![image-2.png](attachment:image-2.png)
#
#
# Veamos un ejemplo de una prueba A/B paso a paso.
#
# Imagina que tienes una tienda online y el 10 por ciento de los visitantes de tu sitio web hacen una compra. Quieres realizar una prueba A/B para averiguar si cambiar el tamaño del botón de añadir al carrito aumentará el porcentaje de conversiones o el porcentaje de clientes que compran un producto.
#
# La prueba presenta dos versiones de tu página web, conocidas como versión A y versión B, a un grupo de usuarios seleccionados al azar.
#
# La versión A es la página web original. La versión B es la página web con el botón de añadir al carrito más grande. La prueba dirige a la mitad de los usuarios a la versión A y a la otra mitad a la versión B. La prueba dura dos semanas. Una vez finalizada la prueba, un análisis estadístico de los resultados indica que el botón más grande de la versión B provocó un aumento de las compras. El porcentaje de conversiones de la versión B es del 30 por ciento. Esto es tres veces mayor que el porcentaje de conversiones de la versión A, que es del 10 por ciento.
#
# Es un aumento notable. Gracias a tu prueba A/B, tu empresa tiene una razón basada en datos para reemplazar la página web actual por la versión B y aumentar el tamaño del botón de añadir al carrito.
#
# ![image-3.png](attachment:image-3.png)
#
#
# ### A/B test steps
#
# - La prueba A/B analiza un pequeño grupo de usuarios extraídos de la población total de todos los usuarios que visitan el sitio web. En las estadísticas, llamamos **muestra** a este grupo más pequeño.
#
# > La muestra es un subconjunto de la población en general.
#
# Puede usar los datos de una muestra para hacer inferencias o sacar conclusiones sobre toda la población.
#
# Los profesionales de datos utilizan estadísticas inferenciales para hacer inferencias sobre un conjunto de datos basándose en una muestra de los datos.
#
# ![image-4.png](attachment:image-4.png)
#
# En otras palabras, las estadísticas son una herramienta poderosa para predecir resultados que no conoces utilizando datos que sí conoces.
#
# Por ejemplo, no tiene forma de saber cómo se comportarán los próximos 100 000 visitantes del sitio web. Lo que puede hacer es observar a los próximos 1000 visitantes y, a continuación, utilizar estadísticas inferenciales para predecir cómo se comportarán los siguientes 99 000.
#
# Como descubrirás, las estadísticas pueden ayudarte a hacer esa predicción con precisión.
# Esta es la razón por la que observar una muestra mediante Pruebas A/B puede ser tan valioso para las empresas.
#
# Pueden usar los resultados de la prueba para hacer cambios que mejoren su negocio.
#
# > El muestreo, el proceso de selección de un subconjunto de datos de una población, es una parte fundamental de una prueba A/B.
#
# - Antes de realizar la prueba, debe decidir el tamaño de la muestra o el número de usuarios de la prueba.
#
# - Elegir el tamaño de muestra correcto le ayuda a obtener resultados de pruebas válidos y a evitar errores estadísticos. Por ejemplo, usarás las estadísticas para ayudarte a determinar si necesitas usar un tamaño de muestra de 1000 o 10 000 para predecir el comportamiento de los clientes con precisión.Como cualquier prueba estadística, una prueba A/B no puede predecir el comportamiento del usuario con un 100 por ciento de certeza.
#
#
# - Lo que pueden hacer las estadísticas es construir un **intervalo de confianza** o un rango de valores que describa la incertidumbre o que rodea a una estimación.
#
# ![image-5.png](attachment:image-5.png)
#
#
# Saber cómo construir e interpretar un intervalo de confianza le ayuda a tomar decisiones informadas sobre todos los usuarios en función de la muestra de prueba.
#
# Con las estadísticas, puedes cuantificar la incertidumbre de tu prueba A/B y compartir esta información con las partes interesadas para ayudarlas a interpretar los resultados.
#
# - Una vez finalizada la prueba, tendrás que determinar la significación estadística de tus resultados. Significación estadística se refiere a la afirmación de que los resultados de una prueba o experimento no se pueden explicar únicamente por casualidad. Por ejemplo, ¿la diferencia entre la versión A y la versión B se debe a una casualidad aleatoria o al hecho de que cambiaste el botón de añadir al carrito?
#
# ![image-6.png](attachment:image-6.png)
#
# > Una prueba de hipótesis es un método estadístico que ayuda a responder a esta pregunta.
#
# La prueba ayuda a cuantificar si es probable que el resultado se deba al azar o si es estadísticamente significativo. Una prueba de hipótesis le brinda soporte basado en datos para cambiar su página web a la versión B o para mantenerla igual con la versión A.
#
# El software puede ayudarlo a calcular problemas matemáticos complejos. Sin embargo, tener un conocimiento práctico de las estadísticas te permite diseñar , realizar e interpretar correctamente los resultados de una prueba real.
