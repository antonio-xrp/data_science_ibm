# %% [markdown]
# Hasta ahora, hemos estado hablando de distribuciones de probabilidad discretas en las que los resultados de los experimentos están representados por números enteros contables. Por ejemplo, tirar un dado puede dar como resultado dos o tres, pero no valores decimales, como 2,178 o 3,394.
#
# Ahora pasaremos de distribuciones de probabilidad discretas a distribuciones de probabilidad continuas.
#
# Recuerde que la probabilidad continua se refiere a los resultados que pueden adoptar todos los valores de un rango de números;por lo general, se trata de valores decimales que se pueden medir, como la altura, el peso, el tiempo o la temperatura. Por ejemplo, puede seguir midiendo el tiempo con más precisión: 1,1 segundos, 1,12 segundos, 1,1257 segundos, etc.
#
# ### DISTRIBUCION NORMAL
#
# Exploraremos la distribución de probabilidad más utilizada en estadística, la distribución normal.
#
# La distribución normal es una distribución de probabilidad continua que es simétrica en ambos lados de la media y tiene forma de campana. A menudo se denomina curva de campana porque su gráfica tiene la forma de una campana con un pico en el centro y dos lados inclinados hacia abajo;ademas, se conoce como distribución gaussiana en honor al matemático alemán Carl Gauss, quien describió por primera vez la fórmula de la distribución.
#
# ![image.png](attachment:image.png)
#
# Ya que estamos hablando del tema de las fórmulas, si quieres obtener más información sobre esta fórmula, consulta la lectura correspondiente donde se explica con más detalle.
#
# La distribución normal es la distribución de probabilidad más común en estadística porque muchos tipos diferentes de conjuntos de datos muestran una curva en forma de campana.
#
# Por ejemplo, si muestreas aleatoriamente a 100 personas, descubrirás una curva de distribución normal para variables continuas, como: altura, peso, presión arterial, puntajes de coeficiente intelectual, salarios y más.
#
# Por ejemplo, piense en los resultados típicos de las pruebas estandarizadas:
#
# - la mayoría de las personas obtendrán una puntuación cercana a la puntuación promedio o media.
#
# - Un menor número de personas obtendrán una puntuación inferior o superior al promedio, más alejadas de la media.
#
# - Un porcentaje muy pequeño de personas obtendrá una puntuación extremadamente alta o extremadamente baja, muy lejos de lo malo.
#
# Esta distribución de puntuaciones genera una curva en forma de campana, la mayoría de los valores de los datos están relativamente cerca de la media, cuanto más lejos esté un valor de la media, es menos probable que se produzca.
#
# ![image-2.png](attachment:image-2.png)
#
# En una curva normal, el eje x se refiere al valor de la variable que estás midiendo y el eje y se refiere a la probabilidad de que observes el valor.
#
# En el caso de los puntajes de las pruebas, el eje x es el puntaje bruto y el eje y es el porcentaje de la población que obtiene ese puntaje.
#
# ### Use the normal distribution
#
# Los profesionales de datos utilizan la distribución normal para modelar todo tipo de conjuntos de datos diferentes en los campos de los negocios, la ciencia, el gobierno, el aprendizaje automático y otros.
#
# Comprender la distribución normal también es importante para los métodos estadísticos más avanzados, como las pruebas de hipótesis y el análisis de regresión. Además, muchos algoritmos de aprendizaje automático asumen que los datos se distribuyen normalmente.
#
# ### Caracteristicas
#
# Todas las distribuciones normales tienen las siguientes características:
#
# - la forma es una curva en forma de campana
#
# - la media se encuentra en el centro de la curva,
#
# - la curva es simétrica en ambos lados del centro
#
# - el área total bajo la curva es igual a 1.
#
# Para aclarar las características de la distribución normal, grafiquemos los pesos de las manzanas crujientes.
#
# ![image-3.png](attachment:image-3.png)
#
# Supongamos que los pesos de las manzanas crujientes se distribuyen aproximadamente de forma normal con una media de 100 gramos y una desviación estándar de 15 gramos.
#
# - Primero, encuentra la media en el centro de la curva, este es también el punto más alto o pico de la curva y este punto de datos representa el resultado más probable del conjunto de datos, un peso medio de 100 gramos.
#
# - En segundo lugar, observe que la curva es simétrica en cada lado de la media, el cincuenta por ciento de los datos está por encima de la media y el 50 por ciento está por debajo de la media.
#
# - En tercer lugar, cuanto más lejos esté un punto de la media, menor será la probabilidad de esos resultados, los puntos más alejados de la media representan los resultados menos probables del conjunto de datos. Se trata de manzanas que tienen pesos más extremos, ya sean bajos o altos.
#
# - Por último, el área bajo la curva es igual a 1, esto significa que el área bajo la curva representa el 100 por ciento de los posibles resultados de la distribución.
#
#
# En una distribución normal, la distancia entre un punto de datos y la media se mide con frecuencia en desviaciones estándar.
#
# > Como recordatorio, la desviación estándar calcula la distancia típica de un punto de datos con respecto a la media del conjunto de datos.
#
# Si bien la media se refiere al centro de los datos, la desviación estándar mide la dispersión, a medida que aumentan las desviaciones estándar, los valores de los datos se alejan más de la media.
#
# En nuestro ejemplo de manzana:
#
# - el peso medio es de 100 gramos y la desviación estándar es de 15 gramos, por lo que una manzana que esté una desviación estándar por encima de la media pesará 115 gramos con un peso medio de 100 gramos más la desviación estándar de 15 gramos.
#
# -  Una manzana que esté una desviación estándar por debajo de la media pesará 85 gramos o 100 gramos menos 15 gramos.
#
# - Una manzana con dos desviaciones estándar por encima de la media pesará 130 gramos, y una manzana con dos desviaciones estándar por debajo de la media pesará 70 gramos.
#
#
#
# ### The empirical rule
#
# Los valores de una curva normal se distribuyen en un patrón regular en función de su distancia a la media. Esto se conoce como regla empírica.
#
# Establece que:
#
# - para un conjunto de datos determinado con una distribución normal, el 68 por ciento de los valores se encuentran dentro de una desviación estándar de la media,
#
# - el 95 por ciento de los valores se encuentran dentro de dos desviaciones estándar de la media
#
# - el 99,7 por ciento de los valores se encuentran dentro de las tres desviaciones estándar de la media.
#
# La regla empírica puede darle una idea clara de cómo se distribuyen los valores de su conjunto de datos, lo que le ayuda a ahorrar tiempo y a comprender mejor los datos.
#
# Sigamos con nuestro ejemplo de manzana.
#
# - La regla empírica indica que la mayoría de las manzanas con un 68 por ciento caerán dentro de una desviación estándar del peso medio de 100 gramos, esto significa que el 68 por ciento de las manzanas pesarán entre 85 gramos, una desviación estándar por debajo de la media, y 115 gramos, una desviación estándar por encima de la media.
#
# - El 95% de las manzanas pesarán entre 70 y 130 gramos o dentro de dos desviaciones estándar de la media.
#
# - Casi todas las manzanas, o el 99,7 por ciento, pesarán entre 55 gramos y 145 gramos, o dentro de las tres desviaciones estándar de la media.
#
# La regla empírica es útil para estimar datos, especialmente para conjuntos de datos grandes, como los datos de altura y peso de toda una población. Puede usar la regla empírica para obtener una estimación inicial de la distribución de los valores en su conjunto de datos, por ejemplo, qué porcentaje de valores estará dentro de una , dos o tres desviaciones estándar de la media.
#
# Esto ahorra tiempo y le ayuda a comprender mejor sus datos. Además, conocer la ubicación de los valores en una distribución normal es útil para detectar valores atípicos.
#
# > Recuerde que un valor atípico es un valor que difiere significativamente del resto de los datos. Por lo general, los profesionales de datos consideran que los valores que se encuentran más de tres desviaciones estándar por debajo o por encima de la media son valores atípicos.
#
# Es importante identificar los valores atípicos porque algunos valores extremos pueden deberse a errores en la recopilación o el procesamiento de datos. Estos valores falsos pueden sesgar los resultados del análisis.
#
# Exploremos otro ejemplo de cómo la regla empírica puede ayudarlo a comprender mejor sus datos.
#
# Imagina que tienes un jardín, la altura de tus planos normalmente se distribuye con una media de 32,1 pulgadas y una desviación estándar de 2,2 pulgadas.
#
# ![image-4.png](attachment:image-4.png)
#
# Supongamos que quieres saber qué porcentaje de plantas miden más de 29,9 pulgadas de alto.
#
# Desea que sus plantas tengan al menos esta altura como parte de su plan de diseño de jardines para su patio trasero.
#
# - Primero, averigüe dónde se encuentra el valor 29.9, en la distribución el 20.9 se ubica una desviación estándar por debajo de la media. La regla empírica indica que el 68 por ciento de los valores se encuentran dentro de una desviación estándar de la media. La mitad de estos valores, o el 34 por ciento, están por debajo de la media.
#
# - Ahora sabe que el 34 por ciento de los valores se encuentran entre 29,9 y la media porque 29,9 es una desviación estándar por debajo de la media y el 50 por ciento de todos los valores de una distribución normal están por encima de la media o el centro de la curva.
#
# - La suma de estos dos porcentajes le indicará el porcentaje total de valores superiores a 29,9. El 34 por ciento más el 50 por ciento equivale al 84 por ciento, por lo que el 84 por ciento de sus plantas miden más de 29,9 pulgadas de alto.
#
# La regla empírica le ayuda a comprender rápidamente la distribución general de los valores de los datos. Ahora sabe que la mayoría de sus plantas son lo suficientemente altas para su plan de diseño de jardines.
#
# Como futuro profesional de datos, utilizará la distribución normal para identificar patrones significativos en una amplia variedad de conjuntos de datos.

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# ### Modelar datos con la distribución normal
#
# Recientemente, ha estado aprendiendo sobre las distribuciones de probabilidad continuas y cómo ayudan a los profesionales de datos a modelar sus datos. Recuerde que las distribuciones de probabilidad continua representan variables aleatorias continuas, que pueden tomar todos los valores posibles en un rango de números. Normalmente, se trata de valores decimales que pueden medirse, como la altura, el peso, el tiempo o la temperatura. Por ejemplo, se puede seguir midiendo el tiempo con más precisión: 1,1 segundos, 1,12 segundos, 1,1257 segundos, etcétera.
#
# En este curso, nos centraremos en una única distribución de probabilidad continua: la distribución normal. En esta lectura, aprenderá más sobre las características principales de la distribución normal, y cómo la distribución puede ayudarle a modelar sus datos.
#
# ### Distribuciones de probabilidad continuas
#
# Antes de llegar a los atributos específicos de la distribución normal, vamos a discutir algunas características generales de todas las distribuciones de probabilidad continuas.
#
# ### Densidad de probabilidad y probabilidad
#
# Una función de probabilidad es una función matemática que proporciona probabilidades para los posibles resultados de una variable aleatoria.
#
# Existen dos tipos de funciones de probabilidad:
#
# - Funciones de probabilidad bruta (PMF) representan variables aleatorias discretas
#
# - Las funciones de densidad de probabilidad (FDP) representan variables aleatorias continuas.
#
# Una función de probabilidad puede representarse como una ecuación o un gráfico. Las matemáticas involucradas en las funciones de probabilidad están más allá del alcance de este curso. Por ahora, es importante saber que la gráfica de una FDP aparece como una curva. Usted ha aprendido acerca de la curva de campana, que se refiere a la gráfica de una distribución normal.
#
# Como ejemplo, imagina que tienes datos sobre una muestra aleatoria de cerezos. Suponga que las alturas de los cerezos se distribuyen aproximadamente de forma normal con una media de 15 pies y una desviación estándar de 2 pies.
#
# ![image.png](attachment:image.png)
#
# en una distribución continua, el eje x se refiere al valor de la variable que se está midiendo, en este caso, la altura de los cerezos. El eje y se refiere a la densidad de probabilidad. Tenga en cuenta que la densidad de probabilidad no es lo mismo que la probabilidad.
#
# La distribución de probabilidad para una variable aleatoria continua sólo puede indicarle la probabilidad de que la variable tome un rango o intervalo de valores. Esto se debe a que una variable aleatoria continua puede tener un número infinito de valores posibles. Por ejemplo, la altura de un cerezo elegido al azar podría medir 15 pies, o 15,1 pies, o 15,175 pies, o 15,175245 pies, y así sucesivamente.
#
# Supongamos que desea conocer la probabilidad de que la altura de un cerezo elegido al azar sea exactamente 15,1 pies. Dado que la altura del árbol podría ser cualquier valor decimal en un intervalo dado, la probabilidad de que el árbol sea exactamente cualquier valor es esencialmente cero.
#
# Por tanto, para distribuciones continuas, sólo tiene sentido hablar de la probabilidad de intervalos, como el intervalo entre 14,5 pies y 15,5 pies.
#
# Para hallar la probabilidad de un intervalo, se calcula el área bajo la curva que corresponde al intervalo. Por ejemplo, la probabilidad de que un cerezo tenga una altura entre 14,5 pies y 15,5 pies es igual al área bajo la curva entre los valores 14,5 y 15,5 en el eje x. Esta área aparece como un rectángulo sombreado en el eje x. Esta área aparece como el rectángulo sombreado en el centro del gráfico.
#
# ![image-2.png](attachment:image-2.png)
#
#
# En este caso, el área del rectángulo es de 0,20 aproximadamente. Por lo tanto, hay un 20% de posibilidades de que la altura de un cerezo elegido al azar esté entre 14,5 pies y 15. 5 pies.
#
# **Nota:** los profesionales de los datos suelen utilizar programas estadísticos para calcular probabilidades en una distribución continua.
#
# ### Distribución normal
#
# La distribución normal es una distribución de probabilidad continua que es simétrica respecto a la media y tiene forma de campana. También se conoce como distribución de Gauss, en honor al matemático alemán Carl Gauss, que describió por primera vez su fórmula. La distribución normal suele denominarse curva de campana porque su gráfico tiene forma de campana, con un pico en el centro y dos lados inclinados hacia abajo.
#
# La Distribución normal es la distribución de probabilidad más común en estadística porque muchos tipos diferentes de conjuntos de datos muestran una curva en forma de campana. Por ejemplo, si toma una muestra aleatoria de 100 personas, descubrirá una curva de distribución normal para variables continuas como la altura, el peso, la tensión arterial, el número de calzado, las puntuaciones en los exámenes y mucho más.
#
# Todas las distribuciones normales tienen las siguientes características:
#
# - La forma es una campana de Gauss
#
# - La media se sitúa en el centro de la curva
#
# - La curva es simétrica a ambos lados de la media
#
# - El área total bajo la curva es igual a 1
#
# Utilicemos nuestro ejemplo del cerezo para aclarar las características de la Distribución normal. Recordemos que la altura media es de 15 pies con una desviación típica de 2 pies.
#
# ![image-3.png](attachment:image-3.png)
#
# Puedes observar las siguientes características de la curva normal:
#
# - La media está situada en el centro de la curva, y es también el pico de la curva. La altura media de 15 pies representa el resultado más probable del conjunto de datos.
#
# - La curva es simétrica respecto a la media. el 50% de los datos están por encima de la media y el 50% por debajo de la media
#
# - Cuanto más alejado esté un punto de la media, menor será la probabilidad de esos resultados. Los puntos más alejados de la media representan los resultados menos probables del conjunto de datos. Se trata de árboles con alturas más extremas, ya sean bajos o altos
#
# - El área bajo la curva es igual a 1. Esto significa que el área bajo la curva representa el 100% de los posibles resultados de la distribución
#
# ### La regla empírica
#
# También puede observar que los valores de una curva normal se distribuyen siguiendo un patrón regular, en función de su distancia a la media. Esto se conoce como regla empírica . La regla establece que para un conjunto de datos dado con una distribución normal
#
# - el 68% de los valores se sitúan a menos de 1 desviación típica de la media
#
# - el 95% de los valores se sitúan a menos de 2 desviaciones típicas de la media
#
# - 99.el 7% de los valores se sitúan a menos de 3 desviaciones típicas de la media
#
# ![image-4.png](attachment:image-4.png)
#
# Si se aplica la regla empírica a nuestro ejemplo del cerezo, se obtiene lo siguiente:
#
# - La mayoría de los árboles, es decir, el 68%, estarán dentro de 1 desviación típica de la altura media de 15 pies. Esto significa que el 68% de los árboles medirán entre 13 y 17 pies, es decir, 2 pies por debajo de la media y 2 pies por encima de la media
#
# - el 95% de los árboles medirán entre 11 y 19 pies, es decir, dentro de 2 desviaciones estándar de la media
#
# - Casi todos los árboles, el 99,7%, medirán entre 9 y 21 pies, es decir, dentro de las 3 desviaciones estándar de la media
#
# La regla empírica puede proporcionarle una estimación rápida de cómo se distribuyen los valores en un gran conjunto de datos. Esto ahorra tiempo y ayuda a comprender mejor los datos.
#
# Conocer la ubicación de los valores en una distribución normal también es útil para detectar valores atípicos. Recordemos que un valor atípico es un valor que difiere significativamente del resto de los datos. Normalmente, los profesionales de datos consideran valores atípicos aquellos que se sitúan más de 3 desviaciones estándar por debajo o por encima de la media. Es importante identificar los valores atípicos porque algunos valores extremos pueden deberse a errores en la recogida o el procesamiento de los datos, y estos valores falsos pueden sesgar los resultados.
#
# ### Puntos clave
#
# Como profesional de los datos, es probable que utilice la distribución normal para identificar patrones significativos en una amplia variedad de conjuntos de datos. Comprender la distribución normal también es importante para métodos estadísticos más avanzados, como el Testeo de hipótesis y el Análisis de regresión, sobre los que aprenderá más adelante.
#
# Recursos para obtener más información
#
# Para obtener más información sobre las distribuciones de probabilidad continuas y la distribución normal, consulte los siguientes recursos:
#
# https://sites.nicholas.duke.edu/statsreview/continuous-probability-distributions/
