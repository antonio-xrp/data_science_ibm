# %% [markdown]
# ### Principios de la probabilidad
#
# En primer lugar, quiero darles un poco de contexto sobre los tipos de ejemplos que utilizaremos. Seguiremos haciendo referencia a ejemplos de eventos como lanzar monedas, lanzar dados y robar cartas. Hay un par de razones para ello. Una es histórica.
#
# - La teoría moderna de la probabilidad tiene su origen en el análisis de los juegos, del azar en los siglos XVI y XVII.
#
# - En segundo lugar, y lo que es más importante, se trata de eventos con resultados claramente definidos con los que la mayoría de las personas están familiarizadas. Son solo ejemplos muy útiles de conceptos básicos de probabilidad. Por eso se utilizan en las clases de estadísticas de todo el mundo.
#
# - En primer lugar, la probabilidad de que ocurra un evento se expresa como un número entre 0 y 1.
#
# - Si la probabilidad de un evento es igual a cero, hay un cero por ciento de probabilidades de que el evento ocurra.
#
# - Si la probabilidad de un evento es igual a uno, hay una probabilidad del 100 por ciento de que el evento ocurra. Hay muchas posibilidades entre 0 y 1.
#
# -Si la probabilidad de un evento es igual a 0.5, hay un 50 por ciento de probabilidades de que el evento ocurra o no ocurra.
#
# - Si la probabilidad de un evento es cercana a cero, hay una pequeña probabilidad de que el evento ocurra.
#
# - Si la probabilidad de un evento es cercana a uno, hay una gran probabilidad de que el evento ocurra.
#
# ![image.png](attachment:image.png)
#
# Por ejemplo, la probabilidad de que el precio de una acción suba este año es del 0,05 o del cinco por ciento, entonces es probable que no quieras comprarla. Si es del 0,95 o el 95 por ciento, entonces probablemente sea una buena inversión.
#
# ### Probabilidad
#
# La probabilidad mide la probabilidad de que se produzcan eventos aleatorios. El resultado de un evento aleatorio no se puede predecir con certeza.
#
# Antes de lanzar una moneda o tirar un dado, no sabes el resultado. La moneda puede salir cara o cruz, y un dado puede mostrar cualquier número del uno al seis. Estos son ejemplos de lo que los estadísticos llaman un **experimento aleatorio, también conocido como experimento estadístico**.
#
# 1. **Un experimento aleatorio** es un proceso cuyo resultado no se puede predecir con certeza.
#
# Todos los experimentos aleatorios tienen tres cosas en común.
#
# - El experimento puede tener más de un resultado posible,
# - puedes representar cada resultado posible por adelantado
# - el resultado del experimento depende del azar.
#
# ![image-2.png](attachment:image-2.png)
#
#
# Tomemos el ejemplo de lanzar una moneda al aire.
#
# Hay más de un resultado posible. Puedes representar cada resultado posible y avanzar cara o cruz, y el resultado depende del azar. Hasta que no lances la moneda, no podrás saber si será cara o cruz, ni pensarás en tirar un dado de seis caras. Hay más de un resultado posible y todos los resultados se pueden representar por adelantado: 1, 2, 3, 4, 5 y 6.
#
# El resultado de cualquier tirada depende del azar. Hasta que no tires el dado, no puedes saber qué número aparecerá.
#
# Para calcular la probabilidad de un experimento aleatorio, divide el número de resultados deseados por el número total de resultados posibles.
#
# ![image-3.png](attachment:image-3.png)
#
# Puede recordar que esta también es la fórmula de la probabilidad clásica.
#
# La probabilidad de lanzar una moneda y obtener caras es de una entre dos. Esto es 1 dividido entre 2 y 0,5 o 50 por ciento. La probabilidad de tirar un dado y conseguir dos es de una posibilidad entre seis, esto es 1 dividido 6 es igual a 0,166 repeticiones o alrededor del 16,7 por ciento.
#
# Ahora, llevemos a cabo un experimento aleatorio diferente. Imagina que un frasco contiene 10 canicas, dos canicas son rojas, tres son verdes y cinco son azules. Decides sacar una canica del tarro. Quieres saber la probabilidad de que la canica sea verde. Primero, cuente el número de resultados posibles. Tienes las mismas posibilidades de elegir cualquiera de las 10 canicas. A continuación, averigüe cuántos de estos resultados se refieren a lo que quiere saber.
# La posibilidad de elegir una canica verde. De las 10 canicas en total, tres son verdes. Por lo tanto, la probabilidad de elegir una canica verde es de 3 sobre 10, o 0.3. En otras palabras, tienes un 30 por ciento de posibilidades de elegir una canica verde.
