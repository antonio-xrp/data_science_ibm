# %% [markdown]
# ### The Binomial Distribution
#
# Recientemente, aprendió sobre las distribuciones de probabilidad discretas, que representan eventos aleatorios discretos, como lanzar una moneda o tirar un dado. Con frecuencia, los resultados de eventos discretos se expresan como números enteros que se pueden contar. Por ejemplo, el número de veces que una moneda cae sobre caras en 10 lanzamientos.
#
# Aprenderás sobre una de las distribuciones de probabilidad discretas más utilizadas, la distribución binomial.
#
# La distribución binomial es una distribución discreta que modela la probabilidad de eventos con solo dos resultados posibles, éxito o fracaso. Esta definición asume que cada evento es independiente o no afecta a la probabilidad de los demás, y que la probabilidad de éxito es la misma para cada evento.
#
# Por ejemplo:
#
# - La distribución binomial se aplica a un evento como lanzar la misma moneda 10 veces seguidas, tenga en cuenta que el éxito y el fracaso son etiquetas que se utilizan por conveniencia. Por ejemplo, cada lanzamiento solo tiene dos resultados posibles, cara o cruz y puede optar por etiquetar cara o cruz como un resultado exitoso en función de las necesidades de su análisis. Independientemente de la etiqueta que se aplique a los resultados, es importante saber que **deben excluirse mutuamente**. Como repaso rápido, dos resultados se excluyen mutuamente si no pueden ocurrir al mismo tiempo, **No puedes sacar cara y cruz al lanzar una sola moneda, es lo uno o lo otro.**
#
#
# Los profesionales de datos utilizan la distribución binomial para modelar datos en diferentes campos, como la medicina, la banca, la inversión y el aprendizaje automático.
#
# Por ejemplo:
# - los profesionales de datos utilizan la distribución binomial para modelar la probabilidad de que un medicamento nuevo genere efectos secundarios;
#
# - de que una transacción con tarjeta de crédito sea fraudulenta
#
# - de que el precio de una acción suba o baje de valor.
#
# - En el aprendizaje automático, la distribución binomial se usa con frecuencia para clasificar los datos. Por ejemplo, un profesional de datos puede entrenar un algoritmo para reconocer si una imagen digital de un animal es o no un gato.
#
#
# ### Random experiement
#
# La distribución binomial representa un tipo de evento aleatorio llamado experimento binomial.
#
# Un experimento binomial es un tipo de experimento aleatorio.
#
# Puede recordar que un experimento aleatorio es un proceso cuyo resultado no se puede predecir con certeza.
#
# Todos los experimentos aleatorios tienen tres cosas en común.
#
# - El experimento puede tener más de un resultado posible.
#
# - Puede representar cada resultado posible por adelantado,
#
# - y el resultado del experimento depende del azar.
#
# Por otro lado, un **experimento binomial** tiene los siguientes atributos.
#
# - El experimento consiste en varios ensayos repetidos.
#
# -  Cada ensayo tiene solo dos resultados posibles.
#
# - La probabilidad de éxito es la misma para cada ensayo y cada ensayo es independiente.
#
# ### Binomial experiment
#
# Un ejemplo de un experimento binomial es lanzar una moneda 10 veces seguidas.
#
# Este es un experimento binomial porque tiene las siguientes características.
#
# -  El experimento consiste en 10 intentos repetidos o lanzamientos de monedas.
#
# -  Cada ensayo tiene solo dos resultados posibles, cara o cruz.
#
# -  La probabilidad de éxito es la misma para cada ensayo, si defines el éxito como cabezas, la probabilidad de éxito de cada lanzamiento es la misma, del 50 por ciento.
#
# - Cada prueba es independiente.
#
# El resultado de un lanzamiento de moneda no afecta al resultado de ningún otro lanzamiento de moneda.
#
# Veamos otro ejemplo de un experimento binomial.
#
# Supongamos que quieres saber cuántos clientes devuelven un artículo a una tienda departamental en un día determinado. supongamos que 100 clientes visitan la tienda cada día, el diez por ciento de todos los clientes que visitan la tienda hacen una devolución y Calificas una devolución como exitosa.
#
# Este es un experimento binomial porque:
#
# - hay 100 ensayos repetidos o visitas de clientes.
# - Cada ensayo solo tiene dos resultados posibles, devolución o no devolución.
# - Si etiqueta la devolución como exitosa, la probabilidad de éxito de cada visita de un cliente es la misma, del 10 por ciento.
# -  Cada prueba es independiente.
# - El resultado de la visita de un cliente no afecta al resultado de ninguna otra visita de un cliente.
#
# Es importante entender las características de un experimento binomial porque la distribución binomial solo puede modelar datos para este tipo de eventos. Si estás trabajando con datos para un tipo de evento diferente, necesitas usar un tipo diferente de distribución de probabilidad, como la de Poisson, para modelar los datos.
#
# Una vez que hayas determinado que tu distribución es binomial, puedes aplicar la fórmula de distribución binomial para calcular la probabilidad.
#
#
# No hay necesidad de memorizarlo, puede usar su computadora para hacer los cálculos. Si desea obtener más información, no dude en consultar la lectura correspondiente. En resumen, la fórmula de distribución binomial ayuda a determinar la probabilidad de obtener un número determinado de resultados satisfactorios en un número determinado de ensayos.
#
# ![image.png](attachment:image.png)
#
# Por ejemplo, conseguir un número determinado de caras en un número determinado de lanzamientos de monedas. En esta fórmula,
#
# - k se refiere al número de éxitos,
# - n se refiere al número de ensayos,
# - p se refiere a la probabilidad de éxito en un ensayo determinado y
# - n elige k se refiere al número de formas de obtener k éxitos en n ensayos.
#
# ![image-2.png](attachment:image-2.png)
#
# Exploremos nuestros departamentos, por ejemplo, para entender mejor cómo funciona la fórmula.
# Esta vez,
#
# - supongamos que el 10 por ciento de todos los clientes que visitan la tienda hacen una devolución.
# - Imagina que tres clientes visitan la tienda.
# - Calificas una devolución como exitosa.
#
# Puedes usar la fórmula para determinar la probabilidad de obtener 0, 1, 2 y 3 devoluciones entre los tres clientes.
#
# En el cálculo, X se refiere al número de devoluciones. Me saltaré los cálculos e iré directamente a los resultados.
#
# - Si incluyes la probabilidad de que X sea igual a 0 retornos, el resultado es 0,729.
# - Para la probabilidad de que X sea igual a 1 devolución, el resultado es 0,243.
# - Para la probabilidad de que X sea igual a 2 retornos, el resultado es 0,027.
# - Para la probabilidad de que X sea igual a 3 retornos, el resultado es 0.001.
#
# A continuación, puede usar un histograma para visualizar esta distribución de probabilidad.
#
# ![image-3.png](attachment:image-3.png)
#
# Para una distribución de probabilidad discreta, como la distribución binomial, la variable aleatoria se traza a lo largo del eje x y la probabilidad correspondiente se traza a lo largo del eje y. En este caso, el eje x muestra las visitas por hora: 0, 1, 2 y 3. El eje y muestra la probabilidad de obtener cada resultado.
#
# La distribución binomial permite modelar la probabilidad de eventos con solo dos resultados posibles, éxito o fracaso. Identificar la distribución de sus datos es un paso clave en cualquier análisis y le ayuda a hacer predicciones informadas sobre los resultados futuros.
