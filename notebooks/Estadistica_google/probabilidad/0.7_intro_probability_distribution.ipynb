# %% [markdown]
# ### Introduction to probability distribution
#
# En mi trabajo como profesional de datos, utilizo distribuciones de probabilidad para modelar diferentes tipos de conjuntos de datos e identificar patrones significativos en mis datos.
#
# Una distribución de probabilidad describe la probabilidad de los posibles resultados de un evento aleatorio. Además pueden representar los posibles resultados de eventos aleatorios simples, como lanzar una moneda o tirar un dado. También pueden representar eventos más complejos, como la probabilidad de que un nuevo medicamento trate con éxito una afección médica.
#
# ### Una variable aleatoria
#
# Representa los valores de los posibles resultados de un evento aleatorio. Hay dos tipos de variables aleatorias:
#
# - discretas
# - continuas.
#
# **Una variable aleatoria discreta** tiene un número contable de valores posibles; a menudo, las variables discretas son números enteros que se pueden contar. Por ejemplo, si tiras un dado cinco veces, puedes contar el número de veces que el dado cae sobre dos. si lanzas una moneda cinco veces, puedes contar la cantidad de veces que cae en las caras.
#
# **Una variable aleatoria continua** toma todos los valores posibles en un rango de números; además, cuando se trata de variables continuas, se trata de valores decimales en lugar de números enteros. Por ejemplo, todos los valores decimales entre uno y dos, como 1.1, 1.12, 1.125, etc. Estos valores no son contables, ya que no hay límite para el número posible de valores decimales entre uno y dos. Por lo general, estos son valores decimales que se pueden medir, como la altura, el peso, el tiempo o la temperatura.
#
# Por ejemplo, si mide la altura de una persona u objeto, puede seguir haciendo que su medición sea más precisa, la altura de una persona puede ser de 70,2 pulgadas, 70,23 pulgadas, 70,237 pulgadas, 70,2375 pulgadas, etc. En consecuencia, no hay límite en el número de valores posibles.
#
# ### Discrete or continuous variables
#
# No siempre es evidente de inmediato si una variable es discreta o continua, para ayudarte a elegir entre las dos opciones, puedes usar las siguientes pautas generales:
#
# - Si puede contar el número de resultados, está trabajando con una variable aleatoria discreta. Por ejemplo, contar el número de veces que una moneda cae en caras.
#
# - Si puede medir el resultado, está trabajando con la variable aleatoria continua. Por ejemplo, medir el tiempo que tarda una persona en correr una maratón.
#
#
#
# ### Discrete or continuous distributions
#
# Ahora que hemos explorado las variables aleatorias, volvamos al tema de las distribuciones de probabilidad que describían la probabilidad de cada valor posible de la variable aleatoria.
#
# - Las distribuciones discretas representan variables aleatorias discretas
#
# - las distribuciones continuas representan variables aleatorias continuas.
#
# Una vez que conozca el espacio muestral de una variable aleatoria, puede asignar probabilidades a cada uno de los valores posibles.
#
# ### Sample space
#
# En estadística, puede usar el **término espacio muestral** para describir el conjunto de todos los valores posibles de una variable aleatoria.
#
# Por ejemplo:
# - el lanzamiento de una sola moneda es una variable aleatoria con dos valores posibles: Cara y cruz, así que el espacio muestral es cara y cruz.
#
# - Si tira un dado de seis caras, tendrá una variable aleatoria con seis valores posibles o un espacio muestral de uno, dos, tres, cuatro, cinco y seis.
#
# Veamos un ejemplo de una distribución de probabilidad discreta.
#
# Tomemos como ejemplo el conocido evento aleatorio de una tirada de un solo dado.
#
# - El espacio muestral para un solo rollo de matriz es uno, dos, tres, cuatro, cinco y seis,
#
# - la probabilidad de cada resultado es la misma es uno de cada seis, es decir, el 16,7%.
#
#
# Puede mostrar una distribución de probabilidad discreta en forma de tabla o gráfico.
#
# ![image.png](attachment:image.png)
#
# La tabla de distribución resume la probabilidad de cada resultado posible, la fila superior muestra cada resultado de la tirada de dados y la inferior muestra la probabilidad correspondiente.
#
# ![image-2.png](attachment:image-2.png)
#
# El gráfico de barras o histograma muestra la misma distribución de probabilidad, pero en una forma diferente. Para una probabilidad discreta, la variable aleatoria se traza a lo largo del eje X y la probabilidad correspondiente se traza a lo largo del eje Y. En este caso, el eje X representa cada resultado posible de una sola tirada del uno al seis. El eje Y representa la probabilidad de cada resultado.
#
# Las distribuciones de probabilidad continuas y sus gráficas funcionan de forma un poco diferente a las distribuciones discretas, esto se debe a la diferencia entre variables aleatorias discretas y continuas.
#
# La distribución de probabilidad de una variable aleatoria discreta puede indicarle la probabilidad exacta de cada valor posible de la variable. Por ejemplo, la probabilidad de tirar un dado y obtener un tres es de una sobre seis, es decir, alrededor del 16,7%.
#
# **La distribución de probabilidad de una variable aleatoria continua** solo puede indicarle la probabilidad de que la variable adopte un rango de valores.
#
# Veamos un ejemplo para obtener más información.
#
# Una variable aleatoria continua puede tener un número infinito de valores posibles, imagina que quieres medir la altura de un roble que elegiste al azar de un bosque cercano.
#
# En este ejemplo, la altura del árbol es una variable aleatoria continua, la altura del árbol podría ser, por ejemplo, de 15 pies o 15,2 pies o 15,2187 pies y así sucesivamente.
#
# Puedes seguir añadiendo otro decimal a la medida sin límite.
#
# Ahora supongamos que quiere saber la probabilidad de que la altura del roble sea exactamente de 15,2 pies, porque la altura del árbol puede ser cualquier valor decimal entre el rango de 15 pies y 16 pies. La probabilidad de que el árbol sea exactamente cualquier valor único es esencialmente cero.
#
# En este ejemplo, necesitarás usar una distribución de probabilidad continua para saber la probabilidad de que la altura del roble esté en un rango o intervalo determinado.
#
# Por ejemplo, entre 15 y 16 pies, la probabilidad de cualquier valor específico es cero, por lo que solo tiene sentido hablar de las probabilidades de los intervalos.
#
#
# Una forma cómoda de mostrar **las probabilidades de un rango o intervalo de valores** es con una curva.
#
# En un gráfico, las distribuciones continuas aparecen como curvas. Es posible que haya oído hablar de la curva de campana, que hace referencia a la gráfica de una distribución continua llamada distribución normal.
#
# En la curva, el eje X se refiere al valor de la variable que estás midiendo, en este caso la altura del roble, el eje Y se refiere a algo llamado **densidad de probabilidad**. Se trata de una función matemática que se ocupa de los valores de los intervalos.
#
# ![image-3.png](attachment:image-3.png)
#
# No necesitas concentrarte en la parte matemática ahora mismo, **solo debes saber que la densidad de probabilidad no es lo mismo que la probabilidad**.
#
# Hay mucho más que aprender sobre las distribuciones de probabilidad y cómo pueden ayudarle a modelar diferentes tipos de datos.
