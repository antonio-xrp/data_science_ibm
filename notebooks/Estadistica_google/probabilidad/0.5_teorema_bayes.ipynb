# %% [markdown]
# ### Teorema de Bayes
#
# Anteriormente, aprendió que la probabilidad condicional se refiere a la probabilidad de que ocurra un evento dado que ya ha ocurrido otro evento. Por ejemplo, cuando sacas un as de una baraja de cartas, esto cambia la probabilidad de sacar un segundo as de la misma baraja.
#
#
# Ahora aprenderás a calcular la probabilidad condicional usando el teorema de Bayes.
#
# El teorema de Bayes, también conocido como regla de Bayes, es una fórmula matemática para determinar la probabilidad condicional. Lleva el nombre de Thomas Bayes, un matemático del siglo XVIII de Londres, Inglaterra. El teorema de Bayes proporciona una forma de actualizar la probabilidad de un evento en función de la nueva información sobre el evento.
#
# ![image.png](attachment:image.png)
#
# $[P(A|B) = (P(B|A) * P(A) / P(B))]$
#
# En las estadísticas bayesianas, la probabilidad previa se refiere a la probabilidad de un evento antes de que se recopilen nuevos datos. La probabilidad posterior es la probabilidad actualizada de un evento basada en datos nuevos. Por posterior se entiende que ocurre después. La probabilidad posterior se calcula actualizando la probabilidad anterior utilizando el teorema de Bayes.
#
# Por ejemplo, supongamos que una afección médica está relacionada con la edad. Puedes usar el teorema de Bayes para determinar con mayor precisión la probabilidad de que una persona tenga la afección en función de la edad.
#
# La probabilidad previa sería la probabilidad de que una persona tenga la afección. La probabilidad posterior o actualizada sería la probabilidad de que una persona tenga la afección si se encuentra en un grupo de edad determinado.
#
# El teorema de Bayes es la base del campo de la estadística bayesiana, también conocida como inferencia bayesiana, que es un método poderoso para analizar e interpretar datos en el análisis de datos moderno.
#
# Los profesionales de datos aplicaron el teorema de Bayes en una amplia variedad de campos, desde la inteligencia artificial hasta las pruebas médicas.
#
# Por ejemplo:
# - las instituciones financieras utilizan el análisis bayesiano para evaluar el riesgo de prestar dinero a los prestatarios o para predecir el éxito de una inversión.
#
# - Los minoristas en línea utilizan algoritmos bayesianos para predecir si a los usuarios les gustarán o no ciertos productos y servicios.
#
# - Los especialistas en marketing confían en el teorema de Bayes para identificar las respuestas positivas o negativas en los comentarios de los clientes.
#
# Vamos a ver el teorema en sí. Como siempre, no te preocupes por memorizarlo. El teorema de Bayes es un poco complicado y esta es su versión básica. El teorema de Bayes dice que para dos eventos A y B, la probabilidad de A dado B es igual a la probabilidad de A multiplicada por la probabilidad de B dada A dividida por la probabilidad de B.
#
# Bayes' theorem
#
# P(A|B) = P(B|A) * P(A) / P(B)
#
# - P(A) = Prior probability
# - P(A|B) = Posterior probability
#
# En términos matemáticos, la probabilidad anterior es la probabilidad del evento A. La probabilidad posterior o lo que en última instancia se intenta averiguar es la probabilidad del evento A dado un evento B. La clave del teorema de Bayes es que incluye tanto la probabilidad condicional de B dado A como la probabilidad condicional de Una B.
#
# Si conoces uno de estos probabilidades, el teorema de Bayes puede ayudarte a determinar la otra.
# Veamos un ejemplo. Supongamos que estás planeando un gran evento al aire libre, como una fiesta de graduación. El éxito del evento depende del buen tiempo. El día del evento, notas que la mañana está nublada. Debes averiguar la probabilidad de lluvia, dado que este día comienza nublado. Si hay una alta probabilidad de lluvia, puedes decidir trasladar el evento a un lugar cerrado o incluso cancelarlo.
#
# Conoces la siguiente información: en esta época del año, la probabilidad general de lluvia es del 10 por ciento. Sin embargo, las mañanas nubladas son comunes. Alrededor del 40 por ciento de todos los días comienzan nublados y el 50 por ciento de todos los días lluviosos comienzan nublados. En este ejemplo, tu probabilidad anterior es la probabilidad total de un día lluvioso.
#
# **Probability calculation (Weather information)**
#
# - Overall chance of rain = 10%
# - All days start off cloudy = 40%
# - Rainy days start of cloudy = 50%
#
#
# Los nuevos datos actualizarán esta probabilidad, en este caso, el conocimiento de que la mañana está nublada y que puede llover. En última instancia, lo que quieres saber es la probabilidad de que llueva dado que está nublado. Esta es tu probabilidad posterior. Puede usar el teorema de Bayes para actualizar la probabilidad anterior de que llueva en función de los nuevos datos de que la mañana está nublada.
#
# Cuando trabajas con el teorema de Bayes, es útil averiguar primero qué es el evento A y qué es el evento B. Esto facilita la comprensión de la relación entre los eventos y el uso de la fórmula. Usemos la palabra lluvia para referirnos al evento A, la probabilidad de lluvia.
# Esta es tu probabilidad previa. El evento B es la probabilidad de que el día esté nublado. Usemos la palabra nublado para referirnos al evento B.
#
#
# - Event A = Rain
# - Event B = Cloudy
#
# P(Rain | Cloudy) = P(Cloudy|Rain) * P(Rain) / P(Cloudy)
#
# Ahora, puedes reescribir la probabilidad del evento B dado el evento A como la probabilidad de que esté nublado, dado que llueve.
#
# Finalmente, la probabilidad del evento A, dado el evento B, es la probabilidad de que llueva, dado que está nublado.
#
# Esta es tu probabilidad posterior o la probabilidad actualizada de que el teorema de Bayes te ayudará a calcular. Por último, introduce lo que sabes en la fórmula.
#
# - P(Rain) = 10%
# - P(Cloudy) = 40%
# - P(Cloudy|Rain) = 50%
#
# P (Rain|Cloudy) = (0.1 * 0.5)/ 0.4 = 0.125 = 12%t555
#
#
# La probabilidad de lluvia es del 10 por ciento, la probabilidad de que esté nublado es del 40 por ciento, la probabilidad de que esté nublado dado que llueve es del 50 por ciento. La probabilidad de lluvia dado que está nublado es de 0,1 veces 0,5, dividida por 0,4. Esto equivale a 0,125 o 12,5 por ciento. Hay un 12,5 por ciento de probabilidades de que llueva hoy. Esta es su probabilidad posterior o la probabilidad actualizada según los datos de que la mañana esté nublada. Las probabilidades siguen a tu favor.

# %% [markdown]
# ---

# %% [markdown]
# ### Calcular la probabilidad condicional con el teorema de Bayes.
#
# Hace poco aprendiste que el teorema de Bay es es una fórmula matemática para determinar la probabilidad condicional. El teorema debe su nombre a Thomas Bayes, un matemático londinense del siglo XVIII. Recordemos que la probabilidad condicional se refiere a la probabilidad de que ocurra un suceso dado que ya ha ocurrido otro. Por ejemplo, cuando sacas un as de una baraja de cartas, cambia la probabilidad de sacar un segundo as de la misma baraja.
#
# En esta lectura aprenderás más sobre las distintas partes del teorema de Bayes y cómo puedes utilizarlo para calcular la probabilidad condicional.
#
# ### Teorema de Bayes
#
# El teorema de Bayes proporciona una forma de actualizar la probabilidad de un suceso basándose en nueva información sobre el suceso.
#
# ### Probabilidad previa y posterior
# En estadística bayesiana, la probabilidad previa se refiere a la probabilidad de un suceso antes de que se recopilen nuevos datos. La probabilidad posterior es la probabilidad actualizada de un suceso basada en nuevos datos.
#
# El teorema de Bayes permite calcular la probabilidad posterior actualizando la probabilidad anterior en función de los datos.
#
# Por ejemplo, supongamos que una enfermedad está relacionada con la edad. Puede utilizar el teorema de Bayes para determinar con mayor precisión la probabilidad de que una persona padezca la enfermedad en función de la edad. La probabilidad previa sería la probabilidad de que una persona padezca la enfermedad. La probabilidad posterior, o actualizada, sería la probabilidad de que una persona padezca la enfermedad si pertenece a un determinado grupo de edad.
#
# ### El teorema
# Examinemos el teorema en sí.
#
# Elteorema de Bayes establece que para dos sucesos cualesquiera A y B, la probabilidad de A dada B es igual a la probabilidad de A multiplicada por la probabilidad de B dada A dividida por la probabilidad de B.
#
# ### Teorema de Bayes
#
# $[P(A∣B)= P(B∣A)∗P(A) / P(B)] $
# ​
#
#
# En el teorema, la probabilidad previa es la probabilidad del suceso A. La probabilidad posterior, o lo que se intenta calcular, es la probabilidad del suceso A dado el suceso B.
#
# - P(A): Probabilidad previa
#
# - P(A|B): Probabilidad posterior
#
# A veces, los estadísticos y profesionales de los datos utilizan el término "probabilidad" para referirse a la probabilidad del suceso B dado el suceso A, y el término "evidencia" para referirse a la probabilidad del suceso B.
#
# - P(B|A): Probabilidad
#
# - P(B): Evidencia
#
# Utilizando estos términos, se puede reformular el teorema de Bayes como:
#
# Posterior = Probabilidad * Previo / Evidencia
#
# ![image.png](attachment:image.png)
#
#
# Puede ser útil pensar en el cálculo desde estas perspectivas diferentes y ayudar a representar el problema en la ecuación.
#
# Una forma de entender el teorema de Bayes es que permite transformar una creencia previa, P(A), en una probabilidad posterior, P(A|B), utilizando datos nuevos. Los nuevos datos son la probabilidad, P(B|A), y la evidencia, P(B).
#
# **Nota:** _Esta lectura proporciona una introducción a los conceptos y términos básicos asociados al teorema de Bayes. Un examen detallado de la estadística bayesiana queda fuera del alcance de este curso. A medidaque avance en su carrera como profesional de los datos, tendrá la oportunidad de explorar más a fondo el teorema de Bayes y sus diversas aplicaciones._
#
# Por ahora, un punto clave que debe recordar es que el teorema de Bayes incluye tanto la probabilidad condicional de B dada A como la probabilidad condicional de A dada B. Si conoce una de estas probabilidades, el teorema de Bayes puede ayudarle a determinar la otra.
#
# Veamos un ejemplo para comprender mejor el funcionamiento del teorema.
#
# **Ejemplo: filtro antispam**
#
# Una aplicación muy conocida del teorema de Bayes en el mundo digital es el filtrado de spam, es decir, predecir si un correo electrónico es spam o no. En la práctica, un filtro de spam sofisticado tiene en cuenta muchas variables diferentes, como el contenido del correo electrónico, su título, si tiene un archivo adjunto, el tipo de dominio de la dirección del remitente (.edu u .org), etc. Sin embargo, podemos utilizar una versión simplificada de un filtro bayesiano de spam para nuestro ejemplo.
#
# Supongamos que desea determinar la probabilidad de que un correo electrónico sea spam si en él aparece una palabra específica. Para este ejemplo, utilicemos la palabra "dinero".
#
# Usted descubre la siguiente información:
#
# - La probabilidad de que un correo electrónico sea spam es del 20%.
#
# - La probabilidad de que la palabra "dinero" aparezca en un correo electrónico es del 15%.
#
# - La probabilidad de que la palabra "dinero" aparezca en un correo spam es del 40%.
#
# En este ejemplo, su Probabilidad previa es la probabilidad de que un correo electrónico sea spam. Su probabilidad posterior, o lo que quiere averiguar en última instancia, es la probabilidad de que un correo electrónico sea spam dado que contiene la palabra "dinero" Los nuevos datos que utilizará para actualizar su probabilidad previa son la probabilidad de que la palabra "dinero" aparezca en un correo electrónico y la probabilidad de que la palabra "dinero" aparezca en un correo electrónico de spam.
#
# Cuando trabaje con el teorema de Bayes, es útil averiguar primero qué es el suceso A y qué es el suceso B; esto facilita la comprensión de la relación entre sucesos y el uso de la fórmula.
#
# Digamos que el suceso A es un mensaje de spam y que el suceso B es la aparición de la palabra "dinero" en un mensaje de correo electrónico. Ahora podemos reescribir el teorema de Bayes utilizando la palabra "spam" para el suceso A y la palabra "dinero" para el suceso B. La fórmula es la siguiente
#
# P(A|B) = P(B|A) * P(A) / P(B)
#
# P (Spam | Dinero) = P(Dinero | Spam) * P(Spam) / P(Dinero)
#
# Quieres averiguar lo siguiente
#
# P(Spam | Dinero), o probabilidad posterior: la probabilidad de que un correo electrónico sea spam dado que la palabra "dinero" aparece en el correo electrónico
#
# Ahora, introduzca sus datos en la fórmula:
#
# - P(Spam), o probabilidad a priori: la probabilidad de que un correo electrónico sea spam = 0,2, o 20%
#
# - P(Dinero), o evidencia: la probabilidad de que la palabra "dinero" aparezca en un correo electrónico = 0,15, o 15%
#
# - P(Dinero| Spam), o probabilidad: la probabilidad de que la palabra "dinero" aparezca en un correo electrónico dado que el correo electrónico es spam = 0,4, o 40%
#
# P (Spam | Dinero) = P(Dinero | Spam) * P(Spam) / P(Dinero) = 0,4 * 0,2 / 0,15 = 0,53333, es decir, alrededor del 53,3%.
#
# Por tanto, la probabilidad de que un correo electrónico sea spam si contiene la palabra "dinero" es del 53,3%.
#
# ### Puntos clave
#
# El teorema de Bayes es la base del campo de la estadística bayesiana, también conocida como inferencia bayesiana, que es un potente método para analizar e interpretar datos en la analítica de datos moderna. Los profesionales de los datos utilizan el teorema de Bayes en una amplia variedad de campos, desde la inteligencia artificial hasta las pruebas médicas.
#
# Tener unos conocimientos básicos del teorema de Bayes le permitirá aprender más sobre estadística bayesiana a medida que avance en su carrera como profesional de los datos.
