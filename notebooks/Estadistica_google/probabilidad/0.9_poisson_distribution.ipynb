# %% [markdown]
# ### The poisson distribution
#
# Como profesional de los datos, conocer las distribuciones de probabilidad es superútil porque los distintos tipos de distribuciones te ayudan a modelar diferentes tipos de datos. Cada vez que trabajo con un nuevo Conjunto de datos, intento comprender si hay un patrón presente en los datos de la distribución.
#
# Conocer la distribución de probabilidad de mis datos también me ayuda a elegir el modelo de aprendizaje automático que mejor funciona. De esta forma, puedo obtener un mejor resultado en menos tiempo. Los profesionales de los datos trabajan con muchos tipos diferentes de distribuciones de probabilidad
#
# **Nos centraremos en dos de las distribuciones de probabilidad discretas más comunes, la Binomial y la Poisson.**
#
# Antes, aprendiste que la distribución binomial representa experimentos con pruebas repetidas que tienen dos posibles resultados, éxito o fracaso.
#
# Ahora, aprenderás sobre las principales características de la distribución de Poisson.
#
# ### Poisson distribution
#
# La distribución de Poisson es una distribución de probabilidad que modela la probabilidad de que ocurra un cierto número de eventos durante un periodo de tiempo específico. Además, también se puede utilizar para representar el número de eventos que ocurren en un espacio específico como una distancia, área o volumen, pero en este curso nos centraremos en el tiempo.
#
# Baron Simeon Denis Poisson, matemático francés, derivó originalmente la distribución de Poisson en 1830. Desarrolló la distribución para describir el número de veces que un jugador ganaría en un difícil juego de azar en un gran número de intentos.
#
# Los profesionales de los datos utilizan la distribución de Poisson para modelar datos, como:
#
# - el número esperado de llamadas por hora para un centro de llamadas de servicio al cliente,
# - visitantes por hora para un sitio web,
# - clientes por día en un restaurante,
# - y fuertes tormentas por mes en una ciudad.
#
# ### Poisson experiment
#
# La distribución de Poisson representa un tipo de experimento aleatorio llamado experimento de Poisson. Un experimento de Poisson tiene los siguientes atributos:
#
# - El número de eventos en el experimento se puede contar.
# - El número medio de eventos que ocurrieron durante un periodo de tiempo específico es conocido
# - cada evento es independiente.
#
# Exploremos un ejemplo.
#
# Imagina que eres un profesional de datos que trabaja para una gran cadena de restaurantes que sirve comida rápida. Sabe que el servicio de autoservicio de un restaurante recibe una media de 2 pedidos por minuto. **Quiere determinar la probabilidad de que un restaurante reciba un cierto número de pedidos en un minuto dado.**
#
# Se trata de un experimento de Poisson porque:
# - se puede contar el número de eventos del experimento.
# - Puede contar el número de pedidos.
# - Se conoce el número medio de eventos que ocurren durante un periodo de tiempo específico. Hay una media de 2 pedidos por minuto
# - cada resultado es independiente.
# - La probabilidad de que una persona haga un pedido no afecta a la probabilidad de que otra persona haga un pedido.
#
# Una vez que sabes que estás trabajando con la distribución de Poisson, puedes aplicar la fórmula de distribución de Poisson para calcular la probabilidad. En resumen, la fórmula le ayuda a determinar la probabilidad de que un cierto número de sucesos ocurran durante un periodo de tiempo específico.
#
#
# ![image.png](attachment:image.png)
#
# - En esta fórmula, la letra griega Lamda se refiere al número medio de sucesos que ocurrieron durante un periodo de tiempo específico.
# - k se refiere al número de Eventos.
# - e es una constante igual a aproximadamente 2,71828.
# - El signo de exclamación significa factorial, una función que multiplica un número por todos los números enteros por debajo de él hasta uno. Por ejemplo, dos factorial es dos multiplicado por uno.
#
#
# Continuemos con nuestro ejemplo de la cadena de restaurantes para entender mejor cómo funciona la fórmula.
#
# Recuerda que el servicio de autoservicio de un restaurante recibe una media de dos pedidos por minuto.
#
# Puedes utilizar la fórmula de Poisson para determinar la probabilidad de que el restaurante reciba 0, 1, 2 ó 3 pedidos en un minuto dado.
#
# Conocer esta información puede ayudar al restaurante a organizar el personal para el autoservicio.
#
# Omitiré los cálculos e iré directamente a los resultados.
#
# ![image-2.png](attachment:image-2.png)
#
# - Si introduces la probabilidad de que X sea igual a 0 pedidos, el resultado es 0,1353.
# - Para la probabilidad de que X sea igual a un pedido, el resultado es 0,2707.
# - Para la probabilidad de que X sea igual a dos pedidos, de nuevo, el resultado es 0.2707.
# - Para la probabilidad de que X sea igual a tres pedidos, el resultado es 0,1805.
#
# A continuación, puede utilizar un histograma para visualizar la distribución de probabilidades.
#
# ![image-3.png](attachment:image-3.png)
#
# El Eje X muestra el número de eventos, en este caso, pedidos por minuto.
# El Eje Y muestra la probabilidad de ocurrencia.
#
# Por ejemplo,
# - la probabilidad de obtener 0 pedidos en un minuto es aproximadamente 0,1353 o 13,5%.5 por ciento.
# - La probabilidad de un pedido es 0,2707 o 27,07 por ciento.
# - La probabilidad de dos pedidos también es 0,2707 o 27,07 por ciento.
# - La probabilidad de tres pedidos es 0,1805 o 18,05 por ciento.
#
# Antes de terminar, comparemos las dos distribuciones discretas de probabilidad que has aprendido recientemente, la binomial y la de Poisson.
#
# A veces puede resultar desafiante averiguar si debes utilizar una distribución binomial o una distribución de Poisson. Para ayudarte a elegir entre las dos, puedes utilizar las siguientes directrices generales.
#
# ![image-4.png](attachment:image-4.png)
#
# Utiliza la distribución de Poisson si:
# - te dan la probabilidad media de que ocurra un Evento durante un periodo de tiempo específico.
# - Quieres averiguar la probabilidad de que ocurra un cierto número de Eventos en ese periodo de tiempo.
# - Por ejemplo, si un centro de llamadas tiene una media de 10 llamadas de atención al cliente por hora, puede utilizar la distribución de Poisson para averiguar la probabilidad de que se produzcan 12 llamadas entre las 02:00 P.M. y las 3PM.
#
# - Utilice la distribución binomial si se le da la probabilidad exacta de que se produzca un Evento
# - desea averiguar la probabilidad de que el Evento se produzca un cierto número de veces en un ensayo repetido.
#
# Por ejemplo, si la probabilidad de obtener cara en cualquier lanzamiento de moneda es del 50 por ciento, se puede utilizar la distribución binomial para hallar la probabilidad de obtener 8 caras en 10 lanzamientos de moneda. Eso es todo para las distribuciones discretas de probabilidad.
#
# En tu futura carrera como profesional de los datos, utilizarás distribuciones discretas como la binomial y la Poisson para entender mejor tus datos y hacer predicciones informadas sobre los resultados futuros.
