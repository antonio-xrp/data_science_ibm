# %% [markdown]
# Recientemente, aprendió sobre la distribución normal y cómo se aplica a muchos tipos diferentes de conjuntos de datos.
#
# ### NORMALIZAR LOS DATOS MEDIANTE PUNTUACIONES Z
#
# Una puntuación z es una medida del número de desviaciones estándar por debajo o por encima de la media poblacional de un punto de datos. Una puntuación z le da una idea de qué tan lejos de la media está un punto de datos.
#
# Por ejemplo:
#
# - La puntuación z es 0, si el valor es igual a la media.
#
# - La puntuación z es positiva si el valor es mayor que la media.
#
# - La puntuación z es negativa si el valor es inferior a la media.
#
# Las puntuaciones Z ayudan a estandarizar los datos.
#
# ### Standarization
#
# En estadística, la estandarización es el proceso de poner diferentes variables en la misma escala.
#
# Las puntuaciones Z también se denominan **puntuaciones estándar** porque se basan en lo que se denomina distribución normal estándar.
#
# ![image.png](attachment:image.png)
#
# - Una distribución normal estándar es simplemente una distribución normal con una media de 0 y una desviación estándar de 1. Las puntuaciones Z suelen oscilar entre -3 y +3.
#
# La estandarización es útil porque permite comparar puntuaciones de diferentes conjuntos de datos que pueden tener diferentes unidades, valores medios y desviaciones estándar.
#
# Los profesionales de datos utilizan las puntuaciones z para comprender mejor la relación entre los valores de los datos dentro de un único conjunto de datos y entre diferentes conjuntos de datos.
#
# Por ejemplo:
#
# - los profesionales de datos suelen utilizar puntuaciones z para la detección de anomalías, que encuentran valores atípicos en los conjuntos de datos.
#
# **Anomaly Deteccion Application**
#
# Las aplicaciones de detección de anomalías incluyen:
#
# - la detección de fraudes en las transacciones financieras,
# - fallas en los productos de fabricación,
# - intrusiones en redes informáticas y más.
#
# Por ejemplo :
#
# - Las diferentes encuestas de satisfacción del cliente pueden tener diferentes escalas de calificación.
#
#
# Una encuesta podría calificar un producto o servicio de 1 a 20, otra de 500 a 1500 y una tercera de 130 a 180.
#
# ![image-2.png](attachment:image-2.png)
#
# Supongamos que el mismo producto obtuvo una puntuación de 9 en la primera encuesta, 850 en la segunda y 142 en la tercera. Estas cifras no significan mucho por sí solas, pero si sabes que todas tienen una puntuación z de 1, o una desviación estándar por encima de la media, puedes comparar de manera significativa las calificaciones de las distintas encuestas.
#
# Una puntuación z para un valor individual se puede interpretar de la siguiente manera.
#
# ![image-3.png](attachment:image-3.png)
#
# - Una puntuación z de 1 es una desviación estándar por encima de la media.
#
# - Una puntuación z de 1.5 es 1.5 desviaciones estándar por encima de la media.
#
# - Una puntuación z de -2,3 es 2,3 desviaciones estándar por debajo de la media.
#
#
# **Puedes usar la siguiente fórmula para calcular una puntuación z:**
#
# - Z: es igual a x menos mu dividido por sigma.
#
# ![image-4.png](attachment:image-4.png)
#
# En esta fórmula, x se refiere a un único valor de datos o puntuación bruta.
#
# - La letra griega mu se refiere a la media poblacional.
# - La letra griega sigma se refiere a la desviación estándar de la población.
#
# Por lo tanto, también podemos decir que Z es igual a la puntuación bruta o al valor de los datos menos la media dividida por la desviación estándar.
#
#
# Por ejemplo,
#
# Supongamos que realizas un examen estandarizado y tienes un puntaje de 133. La prueba tiene una puntuación media de 100 y una desviación estándar de 15.
#
# Suponiendo una distribución normal, puedes usar la fórmula para calcular tu puntuación z.
#
# Tu puntuación z es tu puntuación bruta, 133 menos la puntuación media, 100 dividido por la desviación estándar 15. Esto es 133 menos 100 dividido entre 15 es igual a 33 dividido entre 15 es igual a 2.2.
#
# ![image-5.png](attachment:image-5.png)
#
# Su puntuación Z de 2.2 indica que la puntuación de la prueba está 2.2 desviaciones estándar por encima de la puntuación media o promedio. Es una puntuación muy buena.
#
# ![image-6.png](attachment:image-6.png)
#
#
# Recuerde que la regla empírica indica que el 95% de los valores se encuentran dentro de dos desviaciones estándar de la media.
#
# Su puntuación de 2.2 está más de dos desviaciones estándar por encima de la media.
#
# ![image-7.png](attachment:image-7.png)
#
# as puntuaciones Z son útiles porque nos dan una idea de cómo se compara un valor individual con el resto de la distribución.
#
# Hagamos un examen diferente con una escala de calificación diferente.
#
# Supongamos que obtiene una puntuación de 85 puntos y quiere saber si es una buena puntuación en comparación con el resto de la clase.
#
# Que la puntuación sea buena o no depende de la media y la desviación estándar de todos los puntajes de los exámenes.
#
# Supongamos que las puntuaciones de los exámenes se distribuyen normalmente con una puntuación media de 90 y una desviación estándar de 4, puede utilizar la fórmula para calcular la puntuación z de una puntuación bruta de 85.
#
# ![image-8.png](attachment:image-8.png)
#
# Tu puntuación z es tu puntuación bruta, 85 menos la puntuación media de 90, dividida por la desviación estándar de 4. Esto es 85 menos 90 dividido entre 4 es igual a -5, dividido entre 4 es igual a 1.25. Su puntuación z de -1,25 indica que la puntuación de 85 en el examen está 1,25 desviaciones estándar por debajo de la puntuación media o promedio del examen.
#
# ![image-9.png](attachment:image-9.png)
#
#
# Las puntuaciones Z le dan una idea de cómo se comparan los valores individuales con la media. Como profesional de datos, utilizará las puntuaciones z para comprender mejor la relación entre valores específicos de su conjunto de datos.
