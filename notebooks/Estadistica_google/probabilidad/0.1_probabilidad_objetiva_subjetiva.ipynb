# %% [markdown]
# ### Probabilidad Objetiva frente a probabilidad subjetiva
#
# - La probabilidad le ayuda a medir y cuantificar la incertidumbre y a tomar decisiones informadas sobre resultados inciertos. Por ejemplo, puedes usar la probabilidad para decidir qué ponerte en un día determinado. El pronóstico del tiempo para hoy dice que hay un 70 por ciento de probabilidades de nieve. Según estos datos, decide usar su sombrero , guantes y botas de nieve. Cuando cae la nieve, te mantienes caliente y seco.
#
# - Los profesionales de datos pueden usar la probabilidad para predecir las probabilidades de que una empresa venda una determinada cantidad de productos en un período de tiempo determinado.
#
# - de que una inversión financiera tenga un rendimiento positivo
#
# - de que un candidato político gane una elección o de que un examen médico sea preciso.
#
# ![image.png](attachment:image.png)
#
# Tipos principales de probabilidad: objetiva y subjetiva.
#
#
# ### Probabilidad objetiva vs probabilidad subejtiva
#
# - La probabilidad objetiva se basa en estadísticas , experimentos y mediciones matemáticas.
#
# - La probabilidad subjetiva se basa en los sentimientos, la experiencia o el juicio personales.
#
# ### Probabilidad objetiva
#
# - Los profesionales de datos utilizan la probabilidad objetiva para analizar e interpretar los datos.
#
# Hay dos tipos de probabilidad objetiva: **la clásica y la empírica.**
#
# 1. **La probabilidad clásica** se basa en el razonamiento formal sobre eventos con resultados igualmente probables. Para calcular la probabilidad clásica de un evento, divide el número de resultados deseados por el número total de resultados posibles.
#
# ![image-2.png](attachment:image-2.png)
#
# - Por ejemplo, si lanzas una moneda, el resultado será cara o cruz. La cara y la cruz son términos que se utilizan comúnmente para referirse a las dos caras de la moneda. Solo hay dos resultados posibles y ambos resultados son igualmente probables. La probabilidad de que consigas cara es de una sobre dos o del 50 por ciento, lo mismo ocurre con las colas. O las cartas. Hay 52 cartas en una baraja estándar. Al elegir una carta, tienes una probabilidad entre 52, o el 1,9 por ciento, de conseguir cualquier carta de la baraja, ya sea el as de corazones, el 10 de tréboles o el cuatro de espadas.
#
# Sin embargo, la mayoría de los eventos son más complejos y no tienen resultados igualmente probables. Por lo general, el clima no tiene un 50 por ciento de probabilidades de lluvia o nieve, puede haber un 80 por ciento de probabilidades de que llueva mañana y un 20 por ciento de probabilidades de que ocurra algún otro resultado.
#
# - Si bien la probabilidad clásica se aplica a eventos con resultados igualmente probables, los profesionales de datos utilizan la probabilidad empírica para describir eventos más complejos.
#
# 2. **La probabilidad empírica** se basa en datos experimentales o históricos; representa la probabilidad de que ocurra un evento en función de los resultados anteriores de un experimento o de eventos pasados.
#
# Para calcular la probabilidad empírica, divide el número de veces que ocurre un evento específico por el número total de eventos.
#
# ![image-3.png](attachment:image-3.png)
#
# Por ejemplo, supongamos que realizas una prueba de sabor con 100 personas para averiguar si prefieren un helado con sabor a fresa o con chips de menta. Quieres saber la probabilidad de que una persona prefiera el helado de fresa.
#
# Su prueba de sabor revela que 80 personas prefieren el helado de fresa. Para calcular la probabilidad, divide el número de veces que ocurre el evento de preferir el helado de fresa, 80, por el número total de eventos, 100. 80 dividido por 100 es igual a 0,8 u 80 por ciento. Entonces, la probabilidad de que una persona prefiera la fresa a la menta es del 80 por ciento.
#
#
# > los profesionales de datos utilizan los datos de muestra para hacer inferencias o predicciones sobre poblaciones más grandes.
#
# La estadística inferencial también usa la probabilidad.
#
# Por ejemplo, una empresa minorista podría encuestar a una muestra representativa de 100 clientes para predecir las preferencias de compra de todos sus clientes. Los profesionales de datos confían en la probabilidad empírica para poder hacer predicciones precisas basadas en datos de muestra.
#
# Por ejemplo, en una prueba A/B de un sitio web, prueba una muestra de usuarios para hacer una predicción sobre el comportamiento futuro de todos los usuarios.
#
# Supongamos que la muestra de usuarios prefiere un botón verde para añadir al carrito en lugar de uno azul. De estos datos puede deducir que la mayor población de futuros usuarios probablemente compartirá sus preferencias.
#
# Una prueba A/B le permite hacer una predicción razonable sobre los usuarios futuros en función de la probabilidad empírica. Esta probabilidad puede ayudar a una empresa en línea a tomar decisiones más inteligentes y aumentar las ventas.
#
#
#
# ### Probabilidad Subjetiva
#
# Por el contrario, los resultados de la probabilidad subjetiva se basan en el sentimiento, la experiencia o el juicio personales. Este tipo de probabilidad no implica cálculos formales , análisis estadísticos o experimentos científicos.
#
# Por ejemplo, es posible que tengas la abrumadora sensación de que un determinado caballo ganará una carrera de caballos o de que tu equipo favorito ganará el partido por el campeonato.
#
# Puede que tengas buenas razones para creer, pero tus razones son personales o subjetivas. Su creencia no se basa en análisis estadísticos o experimentos científicos. Por esta razón, la probabilidad subjetiva de un evento puede diferir ampliamente de una persona a otra.
#
# Es importante saber la diferencia entre la probabilidad subjetiva y la objetiva al evaluar una predicción o tomar una decisión.
#
# Por ejemplo, el director ejecutivo de una empresa automotriz puede estar seguro de que el uso de una nueva tecnología para fabricar su camioneta reducirá los costos y aumentará las ganancias. Pero si su predicción solo se basa en el sentimiento personal o en la probabilidad subjetiva, es posible que no sea confiable.
#
# La ciencia de datos basada en el análisis estadístico o la probabilidad objetiva puede ayudar a predecir con precisión el impacto potencial de la nueva tecnología y ayudar al CEO a tomar una decisión informada y basada en datos sobre la adopción de la tecnología.
