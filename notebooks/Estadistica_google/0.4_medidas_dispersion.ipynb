# %% [markdown]
# ### Medidas de dispersión
#
# Hay dos cosas que quiero saber cuando empecé a explorar un nuevo conjunto de datos.
#
# - Primero, la ubicación del centro o las medidas de tendencia central, como la media.
#
# - En segundo lugar, quiero saber qué tan dispersos están los valores desde el centro o las medidas de dispersión, como la desviación estándar.
#
# Para obtener una imagen completa de los datos, es bueno conocer tanto el centro como la dispersión.
#
# - Por ejemplo, los conjuntos de datos con el mismo valor central pueden tener diferentes niveles de variabilidad o dispersión.
#
# - Tome tres conjuntos de datos pequeños. Cada conjunto tiene tres valores que suman 90.
#
# - Cada conjunto tiene la misma media, 90/3 es igual a 30.
#
# - Sin embargo, la variación de los valores en torno a la media es muy diferente.
#
# - En el primer conjunto, los valores 25, 30 y 35 están todos cerca de la media de 30.
#
# - El tercer conjunto, los valores 5, 10 y 75, están mucho más separados de la media.
#
#
# ![image.png](attachment:image.png)
#
# ### Measures of dispersion
#
# Ahora aprenderá cómo las medidas de dispersión, como
# - el rango
# - la desviación estándar, pueden ayudarlo a comprender la dispersión de sus datos.
#
# ### El rango
#
# - El rango es la diferencia entre el valor más grande y el más pequeño de un conjunto de datos.
#
# - Tiene datos sobre la temperatura diaria en grados Fahrenheit para la ciudad de Valle Central, Costa Rica, durante la semana pasada. La temperatura más alta es de 77 grados, la temperatura más baja es de 67 grados. Así que el rango es 10.
#
# - El rango es una métrica útil porque es fácil de calcular y te permite comprender rápidamente la distribución general del conjunto de datos.
#
# Sin embargo, la desviación estándar le da una idea más matizada de la variación de los datos.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Desviación estándar
#
# La Desviación estándar mide la dispersión de los valores respecto a la media del conjunto de datos. Calcula la distancia típica de un punto de datos respecto a la media. Cuanto mayor sea la desviación estándar, más alejados estarán los valores de la media. Cuanto menor sea la desviación estándar, menor será la dispersión de los valores respecto a la media.
#
# - La desviación estándar mide qué tan separados están tus valores de la media de tu conjunto de datos.
#
# - Calcula la distancia típica de un punto de datos con respecto a la media.
#
# - Cuanto mayor sea la desviación estándar, más dispersos estarán los valores con respecto a la media.
#
#
# ### Varianza
#
# - Es el promedio de la diferencia cuadrada de cada punto de datos con respecto a la media.
#
# - Básicamente, es el cuadrado de la desviación estándar.
#
# Revisemos las gráficas de tres distribuciones de probabilidad normales para tener una mejor idea del diferencial.
#
# - Por ahora, solo debes saber que la media es el punto más alto de cada curva, justo en el centro.
#
# Cada curva tiene una desviación estándar diferente.
#
# - El azul es uno, el verde es dos y el rojo es tres.
#
# - La curva azul tiene los menores diferenciales, ya que la mayoría de sus puntos de datos se encuentran cerca de la media. Por lo tanto, la curva azul tiene la desviación estándar pequeña.
#
# - La curva roja tiene la mayor desviación estándar. Tiene la mayor dispersión, ya que la mayoría de sus puntos de datos se alejan más de la media.
#
# ![image-3.png](attachment:image-3.png)
#
#
# ### Standar deviation
#
# Esta es la fórmula para la desviación estándar de una muestra. En otras palabras, la raíz cuadrada de Sigma multiplicada por el paréntesis abierto x menos x barra, el paréntesis cerrado al cuadrado dividido por n menos 1.
#
# ![image-4.png](attachment:image-4.png)
#
#
# Existen diferentes fórmulas para calcular la desviación estándar de una población de una muestra.
#
# > Como recordatorio, los profesionales de datos suelen trabajar con datos de muestra y luego hacen inferencias sobre las poblaciones en función de la muestra.
#
# Por lo tanto, revisaremos la fórmula de una muestra.
#
# - calculando la desviación estándar de un conjunto de datos pequeño, 8, 10 y 12. El cálculo de la desviación estándar implica cinco pasos. Primero, encuentra la media del conjunto de datos. La media es igual a 10.
#
# - Luego, para cada valor x y nuestro conjunto de datos, hallamos la distancia a la media y luego la elevamos al cuadrado.
#
# - Es decir, 8 menos 10 al cuadrado es 4, 10 menos 10 al cuadrado es 0 y 12 menos 10 al cuadrado es igual a 4. Suma todos esos números para obtener 8, luego divide ese total por n menos 1. N se refiere al número total de valores del conjunto de datos, que es 3. Tres menos 1 es igual a 2. Entonces, nuestra suma de 8 dividida por 2 es igual a 4.
#
# ![image-5.png](attachment:image-5.png)
#
# - Finalmente, toma la raíz cuadrada de 4, es decir, 2, la desviación estándar.
#
# ![image-6.png](attachment:image-6.png)
#
#
# Ahora vamos a explorar un ejemplo de cómo la desviación estándar es útil en la vida cotidiana.
#
# L- os meteorólogos utilizan la desviación estándar para pronosticar el tiempo a fin de comprender cuánta variación existe en las temperaturas diarias en diferentes lugares y hacer predicciones más precisas sobre el clima.
#
# - Imagine a dos meteorólogos trabajando en dos ciudades diferentes, la ciudad A y la ciudad B. Durante el mes de marzo, la ciudad A tiene una temperatura media de 66 grados Fahrenheit y una desviación estándar de tres grados.
#
# - La ciudad B tiene una temperatura media de 64 grados Fahrenheit y una desviación estándar de 16 grados.
#
# ![image-7.png](attachment:image-7.png)
#
# Ambas ciudades tienen temperaturas medias similares. En otras palabras, la temperatura promedio general es aproximadamente la misma, pero la desviación estándar es mucho mayor en la ciudad B. Esto significa que hay más variaciones diarias en la temperatura en la ciudad B. El clima puede cambiar drásticamente de un día a otro allí. En la ciudad A, el clima es más constante.
#
# Si el meteorólogo de la ciudad B pronosticara el tiempo basándose en la media, podrían tener una diferencia de 16 grados, lo que provocaría que muchos residentes se sintieran descontentos.
#
# La desviación estándar proporciona al meteorólogo una medida útil de la variación a tener en cuenta y un nivel de confianza sobre su predicción.
#
# Una desviación estándar baja de la temperatura hace que sea mucho más fácil para el meteorólogo de la ciudad A predecir con precisión el clima diario.
#
# Los profesionales de datos han creado una nueva desviación estándar para medir la variación en muchos tipos de datos, como:
#
# - los ingresos por publicidad,
# - los precios de las acciones,
# - los salarios de los empleados y más.
