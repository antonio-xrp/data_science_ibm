# %% [markdown]
# Estrategias de clastering en aplicaciones reales
#
# - Clustering es una técnica de aprendizaje automático que agrupa automáticamente puntos de datos en clusters basados en similitudes. Ejemplo: Identificar géneros musicales, segmentar grupos de usuarios, analizar segmetos de mercado.
#
# - Este método puede utilizar solo una caracteristica o multiples caracteristicas en los datos para formar clusters significativos.
#
# - Clustering es como la clasificacin, pero funciona con datos no etiquetados, encontrando patrones de forma independiente para formar clusters.
#
# ![image.png](attachment:image.png)
#
# Aplicaciones comunes de clasterizado
#
# - Analisis exploratorio, se descubre agrupaciones naturales, como la segmentación de clientes.
# - Reconocimiento de patrones: Agrupa objetos similares y ayuda a la segmentación de imágenes, como en la detección de anomalías médicas.
# - Detección de anomalías: Identifica valores atípicos y detecta fraudes o mal funcionamiento de equipos.
# - Feature Engineering: El clustering crea nuevas carácteristicas o reduce la dimensionalidad, mejorando el rendimiento y la interpretabilidad de los modelos.
# - Data summarization: Clustering simplifica los datos resumiéndolos en un pequeño número de clusters representativos.
# - Data compression: Reduce el tamaño de los datos sustituyendo los puntos de datos por centros de cluster, lo que resulta útil para la compresión de imágenes.
# - Feature selection: Identifica las caracteristicas esenciales que distinguen a los clusters.
#
# Tipos de clusterización
# - Partition-based:
#     - Divide los datos en grupos que no se solapan.
#     - El método mas común es K-means con una varianza mínima.
#     - Es eficiente y escalan bien con grandes conjuntos de datos.
#
# - Density Based:
#     - Crean cluster de cualquier forma (shape)
#     - Adecuados para clustering irregulares y conjunto de datos ruidosos
#     - Ejemplo: DBSCAN
#
# - Hierarchical clustering
#     - Organizan los datos en un árbol de clusters anidados, cada uno de los culaes contine sublusters mas pequeños y genera un dendograma y revela las relaciones entre los conglomerados.
#     - Los dos algoritmos principlaes son:
#         - Agglomerative: Merge clusters
#         - Divisive: Split clusters
#     Estos son eficaces para conjuntos de datos pequeños y medianos.
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# Existen dos estrategias principales para construir árboles de agrupación jerarquica:
# 1. La divisiva
# 2. Aglomerativa
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
