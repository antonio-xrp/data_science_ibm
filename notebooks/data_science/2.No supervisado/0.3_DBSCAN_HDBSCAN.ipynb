# %% [markdown]
# DBSCAN Y HDBSCAN clustering
#
#
# DBSCAN
# - Es un algoritmo de agrupamiento espacial basado en la densidad que crea clústers con un valor de densidad proporcionado por el usuario.
# - El valor de densidad se coloca alrededor de un centroide espacial. El area inmediatamente alrededor del centroide se denomia vecindad DBSCAN
# -  Intenta definir las vecindades de los clústeres con una densidad especificada
# - DBSCAN puede descubrir clústeres de cualquier forma, tamaño o densidad en sus datos.
# - Distingue entre los puntos de datos que forman parte de un clúster y los que deben etiquetarse como ruido
# - Es especialmente útil cuando se trabaja con conjuntos de datos con ruido o valores atípicos, o cuando se desconoce el número de clústeres del conjunto de datos.
#
# ![image.png](attachment:image.png)
#
# DBSCAN Algoritmo
#
# Parametros
#     N: Número mínimo desado de puntosque desea en una vencidad
#     epsilon: Radio epsilon de cada vecindad
#
# Analizando cada punto
#     - Core point = Tiene N puntos incluido el mismo dentro de su vecindad o radio épsilon
#     - Border point (punto fronterizo) = El punto se encuentra dentro de la vecindad, pero no tiene suficientes vecinos para ser un punto central (core point) o punto de ruido.
#     - Noise point = Punto aislado de todos los vecindarios del punto central
#     - Clusters: Los clusters crecen a partir de puntos centrales al incluir a sus vecinos.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# DBSCAN Experiment
#
# - DBSCAN no es iteractivo
# - Hace crecer los clústeres de una sola pasada sin actualizarlos una vez que están etiquetados.
# - Los puntos restantes sin asignar se consideran ruido.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
#
# HDBSCAN
#
# - Es una variante de DBSCAN que no requiere configurar ningún parámetro, lo que lo hace aún más flexible que el original.
# - Tambien es menos sencible al ruido y a los valores atípicos.
# - Establidad de cluster: Se refiere a la capacidad de un clúster de no cambiar mucho cuando el tamaño del vecino se ajusta dentro de un rango razonable de radios.
# - Mide la estabilidad de los clústeres para encontrar los radios de vecindad óptimos a nivel local.
# - Como resultado los clústeres son más sólidos y significativos.
#
# ![image-6.png](attachment:image-6.png)
#
# Detalles técnicos:
# - Es una combinación de agrupamiento aglomerativo y basado en la densidad.
# - Comienza identificando cada punto como su propio clúster (es decir, el ruido)
# - Aglomera progresivamente los clústeres en una jerarquía al reducir gradualmente el umbral de densidad.
# - De esa manera se contruye un árbol jerárquico, que se simplifica en un árbol condensado en el que solo se mantienen los clústeres más estables en los diferentes niveles de densidad.
#
# ![image-7.png](attachment:image-7.png)
