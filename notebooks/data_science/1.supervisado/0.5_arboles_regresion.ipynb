# %% [markdown]
# Regression Tree
#
# - Un arboles de regresion predice valores continuos, a diferencia de clasificación que el valor objetivo es categórica
#
# ![image.png](attachment:image.png)
#
# - Los arboles de regresion no utilizan la entropia, en su lugar seleccionan caracteristicas que minimizan el error entre los valores reales. Por ekemplo Error cuadratico medio (MSE), esto equivale como medir la varianza, cuanto menos sea la varianza mas coinciden los valores.
# - Cuandto menor sea la varianza, mayor será la calidad de la división
#
# ![image-2.png](attachment:image-2.png)
#
# - En caso de una función binaria, los datos se separan en dos clases y la calidad de la division solo es el promedio ponderado de los MSE.
#
# - Para una función multiclase, usar estrategias como 1 vs 1 o 1 vs all para generar conjunto de posbiles divisiones binaria.
#
#
# Cómo elegir un conjunto de umbrales de prueba para dividir una función continua?
#
# ![image-3.png](attachment:image-3.png)
#
# Para conjunto de datos muy grande, seleccionar un subconjuto disperso de estos umbrales puede mejorar la eficiencia a costa de precisión.
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Árboles de decision
#
# Un árbol de regresión es análogo a un árbol de decisiones que predice valores continuos en lugar de clases discretas.
#
# La característica distintiva entre la clasificación y la regresión es la característica de los datos objetivo o etiquetados, en la clasificación, la variable objetivo es categórica, como verdadera o falsa, en la regresión, el objetivo es un valor continuo, como la temperatura o el salario.
#
# Cuando un árbol de decisiones se adapta para resolver problemas de regresión, se denomina árbol de regresión.
#
# ![image.png](attachment:image.png)
#
# ### Classification versus regression trees
#
# Comparemos los árboles de clasificación con los árboles de regresión para entender en qué se diferencian.
#
# El objetivo de un árbol de clasificación es clasificar los datos en conjuntos discretos, mientras que un árbol de regresión tiene como objetivo predecir variables objetivo continuas.
#
# Por lo tanto, la variable objetivo de un árbol de clasificación es categórica pero flotante para un árbol de regresión.
#
# La predicción en los nodos de hoja para un árbol de clasificación es un voto mayoritario etiquetado por clase, mientras que para un árbol de regresión, es el valor promedio de los valores objetivo.
#
# Algunos casos utilizados de árboles de clasificación son la detección de spam, la clasificación de imágenes y el diagnóstico médico.
#
# Los árboles de regresión se utilizan para predecir los ingresos, las temperaturas y el riesgo de incendios forestales.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Creating regression trees
#
# Los árboles de regresión se crean dividiendo recursivamente el conjunto de datos en subconjuntos para minimizar la varianza o el Error Cuadrático Medio (ECM) de los valores objetivo. Este proceso genera una estructura en forma de árbol y reduce la dispersión de los valores predichos dentro de cada nodo
#
# ![image-3.png](attachment:image-3.png)
#
# Consideremos este ejemplo.
#
# Dada una característica continua de un conjunto de datos y un valor de umbral de prueba, alfa, los datos de un nodo se dividen en dos subconjuntos según si los datos son mayores o menores que alfa, y los puntos correspondientes se asignan a los nodos izquierdo y derecho.
#
# Si la función es binaria y consta de dos clases, la división se realizará de acuerdo con las dos clases.
#
# ![image-4.png](attachment:image-4.png)
#
# ### Predicting values
#
# - Realiza una predicción en cada nodo basándose en un esquema de votación por clase, como ocurre con los árboles de decisión, o utilizando el promedio de los valores objetivo del nodo.
#
# - El valor previsto, y-hat, para un nodo dado se define como el promedio de los valores objetivo reales, y, i, de los puntos de datos del nodo.
#
# - Puedes usar otras estadísticas, como el valor de la mediana, para asignar la predicción, esto sería preferible cuando los datos están sesgados
#
# - En el caso de los datos distribuidos normalmente, la mediana es comparable a la media, pero es más caro calcularla.
#
# ![image-5.png](attachment:image-5.png)
#
# ### Splitting criterion
#
# - En lugar de utilizar los criterios de entropía o la información obtenida para medir la calidad de una división, como en el caso de los árboles de decisión, los árboles de regresión seleccionan características que minimizan el error entre los valores reales, y, i, en los nodos resultantes, y el valor previsto, y-hat.
#
# ![image-6.png](attachment:image-6.png)
#
# Un criterio natural para medir la calidad de división de una característica determinada es el error cuadrático medio (MSE). Tenga en cuenta que esto equivale a medir la varianza de los valores objetivo dentro de cada nodo, lo que mide qué tan dispersos están los valores. Cuanto menor sea la varianza, más coinciden los valores.
#
# ![image-7.png](attachment:image-7.png)
#
# ### Quality of split
#
# Para medir la calidad de una división, se puede usar el promedio ponderado de las MSE de cada nodo dividido. El promedio ponderado se calcula como el MSE promedio igual a uno sobre el número de observaciones en los dos nodos divididos, multiplicado por la suma del número de observaciones en la división izquierda multiplicado por el MSE de la división izquierda y el número de observaciones en la división derecha multiplicado por el MSE de la división derecha.
#
# Cuanto menor sea este valor, menor será la varianza y, por lo tanto, mayor será la calidad de la división.
#
# ![image-8.png](attachment:image-8.png)
#
# ### Choosing the best split
#
# Durante el entrenamiento, el árbol encuentra la característica y el umbral que mejor dividen cada nodo.
#
# Para cada posible división de una función, el árbol calcula el MSE para los subconjuntos izquierdo y derecho.
#
# El MSE de la división es un promedio ponderado de los MSE de los subconjuntos.
#
# Se elige la división con el MSE con la menor ponderación.
#
# Este proceso minimiza la varianza en los valores pronosticados y mejora la precisión del árbol de regresión.
#
# ![image-9.png](attachment:image-9.png)
#
# ### Categorical feature splits
#
# En el caso de una función binaria, en lugar de utilizar umbrales, los datos simplemente se separan en sus dos clases y la calidad de la división es solo el promedio ponderado de los MSE de la clase.
#
# El MSE ponderado solo tiene un resultado posible, por lo que ya está optimizado. "Para características categóricas con múltiples niveles, evalúe diferentes particiones binarias de las categorías y seleccione la partición que minimice el MSE ponderado."
#
# Luego, para cada división binaria, calcule el promedio ponderado de las MSE.
#
# Seleccione la división que minimice el MSE ponderado y, por lo tanto, la varianza de predicción más baja.
#
# ![image-10.png](attachment:image-10.png)
#
# ### Continuous feature trial thresholds
#
# ¿Cómo se puede elegir un conjunto de umbrales de prueba para dividir una función continua?
#
# Hay muchas maneras, he aquí una estrategia.
#
# - Comience por ordenar los valores de la función de modo que Xi sea menor o igual a Xj, para todos los índices i menores que j.
#
# - Elimine los valores duplicados para que Xi sea estrictamente inferior a Xj, para todos i menores que j.
#
# - Defina los umbrales candidatos, αi como los puntos medios entre cada par de valores consecutivos, αi es la mitad de Xi más Xi más 1.
#
# - Elija el umbral que minimice el MSE ponderado para su división de datos.
#
# Se trata de un método de búsqueda exhaustivo que no se adapta bien al big data.
#
# ![image-11.png](attachment:image-11.png)
#
# Para conjuntos de datos muy grandes la selección de un subconjunto disperso de estos umbrales puede mejorar la eficiencia a costa de la precisión.
#
# - El método también supone que los valores objetivo, X, están distribuidos uniformemente.
#
# - Para mayor eficiencia, debe tener en cuenta la distribución al muestrear los umbrales.
#
# ![image-12.png](attachment:image-12.png)
#
# ### RECAP
#
# - Aprendió que un árbol de regresión es análogo a un árbol de decisiones que predice valores continuos.
#
# - En la clasificación, la variable objetivo es categórica y en la regresión, el objetivo es un valor continuo.
#
# - Los árboles de regresión se crean dividiendo recursivamente el conjunto de datos en subconjuntos para maximizar la información obtenida de la división de datos.
#
# - El MSE es un criterio natural para medir la calidad de división de una función determinada.
#
# - El árbol de regresión encuentra la función y el umbral que mejor dividen cada nodo durante el entrenamiento.
#
# - La función puede ser binaria o multiclase.
#
# - Por último, aprendió que puede elegir los umbrales de prueba continua de varias maneras, según el tamaño de los datos.
