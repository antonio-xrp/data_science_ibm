# %% [markdown]
# Classification Metrics & Evaluation Techniques
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Classification metrics
#
# 1. Accuracy = Relación entre las instancias pronosticadas correctamente y el número total de instancias del conjunto de datos.
# 2. Confusion Matrix = Es una tabla que desglosa el número de instancias de verdad básica de una clase específica en compración con el número de instancias de clase previstas.
# 3. Precision: mide cuántos de los casos positivos pronosticados son realmente positivos.
# 4. Recall : Mide cuantos de los casos positivos realese se predicen correctamente.
# 5. F1 score : Combina precisión y recuperación para representar la precisión de un modelo.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-10.png](attachment:image-10.png)
#
# Recall en medicina, importante considerar los falsos negativos
#
# ![image-11.png](attachment:image-11.png)
