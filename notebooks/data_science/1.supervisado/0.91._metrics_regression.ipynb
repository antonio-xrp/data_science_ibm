# %% [markdown]
# Regression Metrics and Evaluation Techniques
#
# Predecir un modelo de regresión implica determinar con precisión el modelo puede predecir valores numéricos continuos.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# r2 = Cantidad de varianza en la variable dependiente que la variable independete puede explicar. También se denomina coeficiente de determinacion y mide la bondad del ajusnte del modelo.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
