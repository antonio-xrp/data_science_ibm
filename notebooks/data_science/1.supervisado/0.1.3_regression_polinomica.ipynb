# %% [markdown]
# ### Introduction to Polynomial and Nonlinear Regression
#
# ### Introduction to nonlinear regression
#
# - Statistical method for modeling relationship between dependent variable and independent variables.
# - Represented by a nonlinear equation
# - Equation could be polynomial, exponential, logarithmic, or a nonlinear function
# - Useful for a complex relationship
# - Example: Data set with exponential growth pattern
#
# - Data has a background trend that follows a smoothed curve
# - A smooth, nonlinear curve does a better job at approximating data
# - The straight line "under-fits" the data
#
# - La regresión no lineal es un método estadístico para modelar la relación entre una variable dependiente y una o más variables independientes, donde la relación se representa mediante una ecuación no lineal.
#
# - Esta ecuación puede ser polinómica, exponencial, logarítmica o cualquier otra función que no utilice parámetros lineales.
#
# - La regresión no lineal es útil cuando hay una relación compleja entre las variables que no se pueden capturar a través de una línea recta. Por ejemplo, utilizaría la regresión no lineal cuando utilice un conjunto de datos que siga un patrón de crecimiento exponencial.
#
#
# ![image-9.png](attachment:image-9.png)
#
# ### Example of nonlinear regression
#
# - La línea roja que atraviesa los datos del gráfico de la izquierda es un ajuste razonable. Sin embargo, con datos del mundo real, la relación entre las variables de entrada y las variables objetivo rara vez es lineal.
#
# - Por lo general, los datos tienen una tendencia de fondo que sigue una curva suavizada en lugar de una línea recta. Al igual que en el gráfico de la derecha, es evidente que una curva suave y no lineal hace un mejor trabajo para aproximar los datos que la línea recta. La línea recta no se ajusta a los datos.
#
# ![image.png](attachment:image.png)
#
# ### Nonlinear modeling techniques
#
# Puede usar muchos tipos de métodos de regresión no lineal para modelar su conjunto de datos.
#
# - La regresión polinomial utiliza una regresión lineal ordinaria para ajustar indirectamente los datos a las expresiones polinómicas de las entidades, en lugar de a las propias entidades.
#
# - La regresión no lineal sigue la misma idea, pero basa sus entradas en funciones de las entidades dadas, como el logaritmo o el exponencial de las entidades.
#
# - La regresión no lineal no se reduce necesariamente a regresión lineal como lo hace la regresión polinomial.
#
# ![image-10.png](attachment:image-10.png)
#
# ### Polynomial regression
#
# - En este gráfico, puede ver curvas de regresión lineales, cuadráticas y cúbicas que se ajustan bastante bien a los patrones de los datos. Y este enfoque puede continuar con polinomios de grado arbitrario.
#
# - Podemos llamar a todo esto regresión polinomial, donde la relación entre la variable independiente **x** y la variable dependiente **y** se modela como un polinomio de enésimo grado en x.
#
# ![image-11.png](attachment:image-11.png)
#
# ## Example of polynomial regression
#
# Considere este ejemplo de regresión polinomial ejemplo en el que un buen candidato para un ajuste es un polinomio cúbico o de tercer grado, dado por **y** igual a theta cero más theta uno x más theta dos x al cuadrado más theta tres x al cubo.
#
# ![image-13.png](attachment:image-13.png)
#
# - En este caso, los thetas son los parámetros que se deben estimar y que mejor se ajustan a los datos subyacentes, mediante la introducción de nuevas variables como x el subrayado uno es igual a x, el subrayado dos es igual a x elevado a dos y el subrayado x tres es igual a x elevado a tres.
#
# - El modelo ahora se puede expresar como una combinación lineal de las nuevas variables, ya que y es igual a theta cero más theta uno x uno más theta dos x dos más theta tres x tres.
#
# - Como el modelo resultante se ha linealizado, simplemente puede usar la regresión lineal múltiple ordinaria para encontrar los parámetros de mejor ajuste.
#
# ![image-12.png](attachment:image-12.png)
#
#
# ### Overfitting with polynomials
#
# - Dado cualquier conjunto finito de puntos, siempre es posible encontrar un polinomio de grado suficientemente alto que pase por todos los puntos.
#
# - Un ajuste tan perfecto equivale a un sobreajuste, como se ve en este gráfico.
#
# - El modelo de regresión polinomial memoriza todo, incluido cualquier ruido aleatorio o grandes variaciones, en lugar de comprender los patrones subyacentes.
#
# - Es importante elegir una regresión que se ajuste bien a los datos sin sobreajustarlos. No necesitas capturar todos los detalles, solo la tendencia.
#
# ![image-14.png](attachment:image-14.png)
#
# ### Applications of nonlinear regression
#
# - La regresión polinomial es una forma especial de regresión no lineal.
#
# - Expresa una dependencia no lineal de las entidades de entrada, pero tiene una dependencia lineal de los coeficientes de regresión porque puede transformarse en un problema de regresión lineal. A menudo se denomina simplemente regresión lineal.
#
# - Por el contrario, hay muchas relaciones no lineales complejas del mundo real que no se pueden modelar como polinomios.
#
# ![image-15.png](attachment:image-15.png)
#
# ### Applications of nonlinear regression
#
# Estos ejemplos comunes de regresión no lineal incluyen el crecimiento exponencial o compuesto.
# - Por ejemplo, cómo crecen las inversiones con tasas de interés compuestas.
#
# - Logarítmico. Por ejemplo, la ley de rendimientos decrecientes, cómo las ganancias incrementales en productividad o ganancias pueden reducirse a medida que aumenta la inversión en un factor de producción, como la mano de obra.
#
# - Periodicidad. Por ejemplo, las variaciones estacionales sinusoidales de una cantidad, como las precipitaciones o la temperatura mensuales.
#
# ![image-16.png](attachment:image-16.png)
#
# ### Compound growth example
#
# Consideremos estos datos correspondientes al Producto Interno Bruto, o PIB, de China de 1960 a 2014.
#
# - Cada fila proporciona el PIB anual de China en dólares estadounidenses para el año.
#
# - El gráfico de dispersión muestra una fuerte dependencia del PIB con respecto al tiempo, pero la relación no es lineal. Como puede ver, el PIB aumenta con el tiempo y la tasa de este crecimiento también aumenta.
#
# ![image-18.png](attachment:image-18.png)
#
# - Esta tasa de crecimiento creciente es característica del crecimiento exponencial.
#
# - Un modelo de regresión razonable utiliza entonces una función exponencial, como y-hat igual a theta-cero más theta-uno, e-x.
#
# ![image-17.png](attachment:image-17.png)
#
# ### Productivity by work hour example
#
# Considere el siguiente ejemplo simulado que involucra la productividad humana en función del número de horas consecutivas trabajadas.
#
# - Trabajar más horas al día, en promedio, aumenta la productividad. Sin embargo, después de un límite razonable, digamos 6 horas de trabajo, cada hora de trabajo adicional genera menos productividad por hora que la hora anterior.
#
# - Este es un ejemplo de rentabilidad decreciente. Las primeras 6 horas del modelo muestran un aumento lineal de la productividad acumulada, pero luego, los rendimientos se ralentizan y se vuelven logarítmicos.
#
# ![image-19.png](attachment:image-19.png)
#
# ### Linear or nonlinear regression
#
# Hay muchos métodos para determinar qué tipo de modelo de regresión necesita.
#
# - Una técnica consiste en determinar visualmente si la relación es lineal o no lineal.
#
# - El análisis de los gráficos de dispersión de la variable objetivo comparándolos con cada variable de entrada puede revelar patrones en las dependencias.
# - Intente expresar estos patrones como funciones matemáticas y determine si son lineales, exponenciales, logarítmicas o sinusoidales.
#
# - Genere modelos y analice sus resultados.
#
# - Siempre existe la posibilidad de que sus datos no tengan relación con su objetivo. Puede interpretar visualmente los errores del modelo trazando sus predicciones comparándolas con los valores objetivo reales.
#
# ![image-20.png](attachment:image-20.png)
#
# ### Optimizing nonlinear models
#
# ¿Cómo se puede encontrar un modelo no lineal óptimo?
#
# - Si tiene una expresión matemática para el modelo propuesto, puede usar una técnica de optimización como el descenso de gradientes para encontrar los parámetros óptimos.
#
# - De lo contrario, si no se ha decidido por un modelo de regresión específico, puede seleccionar entre muchos modelos de aprendizaje automático.
#
# - Algunas opciones incluyen árboles de regresión, bosques aleatorios, redes neuronales, máquinas de vectores de soporte, máquinas de aumento de gradientes y k vecinos más cercanos.
#
# ![image-21.png](attachment:image-21.png)
#
# ### Recap
#
# - La regresión no lineal usa ecuaciones polinómicas, exponenciales y logarítmicas para modelar los datos.
#
# - Se usa cuando la relación entre las variables no se puede capturar a través de una línea recta.
#
# - Aprendió a usar la regresión polinomial para ajustar los datos a las expresiones polinómicas de las entidades. El modelo de regresión polinomial lo memoriza todo, incluido cualquier ruido aleatorio o grandes variaciones, en lugar de comprender los patrones subyacentes.
#
# - Hay muchas relaciones no lineales complejas del mundo real que no se pueden modelar como polinomios. Algunos ejemplos comunes de regresión no lineal incluyen el crecimiento exponencial o compuesto, el logarítmico y la periodicidad.
#
# - Hay muchos métodos para determinar qué tipo de modelo de regresión necesita. Puede analizar los gráficos de dispersión de la variable objetivo comparándolos con cada variable de entrada para revelar los patrones de las dependencias.
#
# - Para encontrar un modelo no lineal óptimo, puede seleccionar entre muchos modelos de aprendizaje automático, como árboles de regresión, bosques aleatorios y k vecinos más cercanos.
