# %% [markdown]
# ### INTRODUCCIÓN A LA REGRESIÓN LOGÍSTICA
#
# La regresión logística es una técnica de modelado estadístico que predice la probabilidad de que una observación pertenezca a una o dos clases, como verdadera o falsa. En el aprendizaje automático, la regresión logística se refiere a un clasificador binario basado en la regresión logística estadística.
#
# ![image.png](attachment:image.png)
#
# ### What is logistic regression?
#
# Al elegir una probabilidad umbral (TRHESHOLD), el predictor de probabilidad se convierte en un clasificador binario simplemente asignando cada observación a una clase si su probabilidad es mayor que el umbral y a la otra clase si su probabilidad es menor que el umbral.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Comprendamos cuándo la regresión logística es una buena opción.
#
#
# - En primer lugar, cuando el objetivo de los datos es binario, se indica como 0 o 1.
#
# - En segundo lugar, cuando necesitas la probabilidad de un resultado, como la probabilidad de que un cliente compre un producto.
#
# ![image-3.png](attachment:image-3.png)
#
#
# - Si los datos se pueden separar linealmente, el límite de decisión (decision bounday) de la regresión logística es una línea, un plano o un hiperplano. Por ejemplo, theta 0 más theta 1 x 1 más theta 2 x 2 es mayor que 0.
#
# - En tercer lugar, cuando desea comprender el impacto de una característica independiente, le permite seleccionar las mejores características en función del tamaño de los coeficientes o pesos de sus modelos.
#
# ![image-4.png](attachment:image-4.png)
#
# ### Aplicaciones de regresion logística
#
# La regresión logística es tanto un predictor de probabilidad como un clasificador binario.
#
# Por ejemplo:
#
# - Puede usarlo para predecir la probabilidad de que una persona sufra un ataque cardíaco en un período de tiempo específico en función del conocimiento de su edad, sexo e índice de masa corporal.
#
# -  La probabilidad de que aparezca una afección o enfermedad específica, como la diabetes, en función de las características observadas de ese paciente, como el peso, la altura, la presión arterial y los resultados de varios análisis de sangre, etc.
#
# - la probabilidad de que un cliente de un servicio basado en suscripción interrumpa su suscripción
#
# - probabilidad de fallo de un proceso, sistema determinado o producto y probabilidad de que un propietario no pague una hipoteca.
#
# ### Ejemplos de regresion logística
#
# Considera un conjunto de datos de telecomunicaciones que te gustaría analizar para predecir qué clientes podrían irse el mes que viene.
#
# - El conjunto de datos comprende datos históricos de clientes, donde cada fila representa un cliente.
#
# - Los datos incluyen información sobre los servicios a los que se ha suscrito cada cliente, la información de la cuenta del cliente, la información demográfica, como el sexo y el rango de edad, y los clientes que se han ido o se han ido en el último mes.
#
# - En este caso, la columna de variables dependientes se denomina rotación (churn).
#
# ![image-5.png](attachment:image-5.png)
#
# - En la regresión logística, puede usar una o más de estas funciones para predecir si los clientes abandonarán la empresa.
#
# ### Modelo de customer churn data
#
# - La regresión logística puede predecir la clase, y, de cada cliente teniendo en cuenta la probabilidad pronosticada, p hat, de que el cliente abandone.
#
# En este caso, p-hat es la probabilidad prevista de que la clase, y, sea 1, dados los datos, x. Supongamos que el objetivo es predecir la pérdida de clientes en función de su edad.
#
# Tiene una característica, la edad, indicada como x, y un objetivo binario, la rotación variable, denotada como y, con dos clases, sí y no, representadas por los valores binarios 1 y 0.
#
# Gráficamente, puede representar los datos con un diagrama de dispersión, donde la clase 0 se indica en rojo y la clase 1 en azul.
#
# ![image-6.png](attachment:image-6.png)
#
#
# Con la regresión lineal, puede ajustar una línea a través de los datos representados como y, que es igual a theta 0 más theta 1 x 1. Esta línea tiene dos parámetros, donde theta 0 es la intersección en y de la línea y theta 1 es su pendiente. Theta 1 también se denomina vector de ponderación o confianza de la ecuación. Un problema es que el valor y-hat de la predicción aumenta indefinidamente con la edad, porque la línea dura para siempre. Obviamente, no puede usar la regresión lineal directamente para predecir la pérdida de clientes.
#
# De alguna manera, los valores pronosticados deben estar contenidos dentro del rango de 0 a 1.
#
# ![image-7.png](attachment:image-7.png)
#
# Una forma de mantener los valores pronosticados dentro del rango de 0 a 1 es usar un umbral, como 0.5, para diferenciar las clases. Puede escribir una regla que le permita separar la clase 0 de la clase 1. Si el valor de y-hat es inferior a 0,5, la clase es 0; de lo contrario, la clase es 1.
#
# ![image-8.png](attachment:image-8.png)
#
#
# Observe que en la función step, no importa qué tan grande sea el valor, siempre que sea mayor que 0.5, simplemente es igual a 1. E independientemente de lo negativo que sea el valor y-hat, la salida es 0 si es inferior a 0,5. En otras palabras, no hay diferencia entre un cliente de 20 años y un cliente de 100 años.
# El resultado sería 1. ¿No sería bueno usar una línea más suave que proyectara estos valores entre 0 y 1? De hecho, el método actual no proporciona la probabilidad de que un cliente pertenezca a una clase, que es el objetivo.
#
#
# ![image-9.png](attachment:image-9.png)
#
#
# Considere la función sigmoidea, sigma de x, también conocida como función logit, que se define como 1 sobre la suma de 1 y e igual a menos x. Esta gráfica muestra que para x es igual a 0, la función sigmoidea es 0.5. A medida que x crece, la función sigmoidea se acerca a 1, y a medida que x se vuelve más negativa, el sigmoide se acerca a 0. Esto significa que la función sigmoidea puede tomar cualquier función continua de x y comprimirla continuamente dentro del rango 0, 1. Define una probabilidad
#
# ![image-10.png](attachment:image-10.png)
#
#
# Ahora el modelo es sigma de y hat, que representa la probabilidad p hat, y que el resultado es 1 dado x. De este modo, puede determinar la probabilidad de que una observación pertenezca a cualquiera de las clases. Para asignar la clase a la observación, simplemente defina un umbral como 0.5 y asigne la observación a 1 si su probabilidad es mayor que 0.5 y 0 en caso contrario. Este umbral se conoce como límite de decisión.
#
# ![image-11.png](attachment:image-11.png)
#
#
#
# ### ¿Cuál es el resultado del modelo de pérdida de clientes cuando utilizamos la función sigmoidea?
#
# La probabilidad de abandono se indica como la probabilidad de que y sea 1 dados los datos x.
# Observe que la probabilidad de que el cliente no abandone es de 1 menos la probabilidad de abandono, ya que las dos probabilidades deben sumar 1.
#
# Por ejemplo, supongamos que la probabilidad de que un cliente permanezca en la empresa se puede mostrar como la probabilidad de abandono teniendo en cuenta los ingresos y la edad del cliente, que podría ser de 0,8.
#
# ![image-12.png](attachment:image-12.png)
#
# Entonces, la probabilidad de que el mismo cliente se quede es de 1 menos 0.8, que es 0.2.
#
#
# #### RECAP
#
# - La regresión logística hace referencia a un clasificador binario basado en la regresión logística estadística o predictor de probabilidad.
#
# - La regresión logística es una buena opción para obtener un objetivo binario, obtener resultados probabilísticos y comprender el impacto de una característica.
#
# - La regresión logística es tanto un predictor de probabilidad como un clasificador binario.
#
# - El objetivo de la regresión logística es construir un modelo para predecir la clase teniendo en cuenta la probabilidad pronosticada.
