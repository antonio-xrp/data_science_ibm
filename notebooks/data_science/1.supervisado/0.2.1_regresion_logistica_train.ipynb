# %% [markdown]
# ### Entrenamiento de un módulo de regresión logística
#
# En el entrenamiento de regresión logística, se buscan los mejores parámetros que asignen las características de entrada a los resultados objetivo, con el fin de predecir las clases con un mínimo de error.
#
# El proceso de capacitación busca encontrar un conjunto de parámetros, también conocidos como theta, que minimicen la función de costo.
#
# ![image.png](attachment:image.png)
#
#
# El proceso de entrenamiento de un modelo de regresión logística comprende varios pasos.
#
# ![image-2.png](attachment:image-2.png)
#
# - En primer lugar, debe elegir un conjunto inicial de parámetros denominado theta. Puede ser una elección aleatoria.
#
# - A continuación, predice la probabilidad de que la clase sea 1 para cada observación de sus datos.
#
# - El siguiente paso es medir el error entre las clases previstas y las clases reales. Este error se denomina función de coste.
#
# - A continuación, se determina un nuevo theta que reduce el error de predicción.
#
# - Por último, debe repetir el proceso hasta que alcance un valor lo suficientemente pequeño para la pérdida del registro o un número máximo especificado de iteraciones.
#
# ### Optimal logistic regression
#
# A continuación, vamos a entender la regresión logística óptima.
#
# ![image-3.png](attachment:image-3.png)
#
# El proceso de crear un límite de decisión mediante la combinación de un modelo lineal y-hat en términos de parámetros theta con una función sigmoidea produce un modelo de clasificación binaria o lo que podría denominarse una regresión logística preliminar. El modelo se denomina preliminar porque no es necesariamente el mejor modelo de regresión logística.
#
# El mejor modelo de regresión logística solo se puede lograr después de la primera pasada, es necesario encontrar los parámetros del modelo, theta. Un paso de optimización busca los mejores parámetros, para lograr la optimización, necesita una métrica que determine la bondad de ajuste del modelo para un conjunto de parámetros determinado.
#
# ### Optimizing logistic regression
#
# La métrica para optimizar la regresión logística es una función de costo denominada pérdida de registro, que debe minimizarse. La pérdida logarítmica es una función de costo que mide en qué medida las probabilidades pronosticadas, p-hat i, coinciden con el yi de la clase real.
#
# La regresión logística busca minimizar esta función de costo, en este caso, se refiere a la cuarta observación de los datos, que está en filas.
#
# La pérdida logarítmica se define menos el promedio sobre i de dos términos. La clase real multiplicada por el logaritmo de la probabilidad pronosticada de que la clase sea 1 más 1 menos la clase real multiplicada por el logaritmo de la probabilidad de que la clase sea 0.
#
# El signo negativo existe porque el logaritmo es negativo para los argumentos entre 0 y 1.
#
# ![image-4.png](attachment:image-4.png)
#
# ### Understanding log-loss
#
# La pérdida de registros favorece las clasificaciones confiables y correctas.
#
# ![image-5.png](attachment:image-5.png)
#
# Por ejemplo:
#
# - cuando la probabilidad pronosticada de la clase 1 es alta y correcta, p-hat i está cerca de 1 para una observación e yi es igual a 1. Al inspeccionar la fórmula, puede convencerse de que la pérdida de registro es pequeña. De hecho, el primer término desaparece porque el término logarítmico tiende a 0 cuando la probabilidad se acerca a 1, mientras que el segundo término desaparece porque el factor 1 menos yi es 0.
#
# - De esta manera, la pérdida de registros penaliza las predicciones confiables e incorrectas. Cuando la probabilidad pronosticada de la clase 0 es alta e incorrecta, es decir, cuando p-hat está cerca de 1 para una observación y la clase real es 0, la pérdida logarítmica es muy grande.
#
# ### Minimizing cost function with gradient descent
#
#
# ![image-6.png](attachment:image-6.png)
#
# - Hay varias formas de detener las iteraciones, pero básicamente, se detiene el entrenamiento cuando la pérdida de registro del modelo es satisfactoria.
#
# - Se pueden usar diferentes técnicas para cambiar los valores de theta, y uno de los métodos más populares es el descenso de gradientes.
#
# ### Minimizing cost function with gradient descent
#
# ![image-7.png](attachment:image-7.png)
#
# - El descenso de gradiente es un enfoque iterativo inteligente para encontrar el mínimo de una función. Ajusta los valores de los parámetros en la dirección del descenso más pronunciado mediante la derivada de la función de pérdida logarítmica.
#
# - El descenso del gradiente depende de una velocidad de aprendizaje específica, que controla hasta qué punto está permitido escalar los parámetros en cada iteración.
#
#
# ### Gradient descent on a surface
#
# ![image-8.png](attachment:image-8.png)
#
# - El objetivo principal del descenso del gradiente es cambiar los valores de los parámetros y encontrar una ruta hacia los parámetros óptimos para minimizar la función de costo.
#
#
# Considere la gráfica, que simula una función de costo de pérdida logarítmica parabólica de los parámetros de prueba theta1, theta2. Esta superficie representa el error para diferentes valores de parámetros.
#
# La pendiente de la superficie apunta en la dirección de la subida más pronunciada. Por lo tanto, el negativo del gradiente apunta en la dirección del descenso más pronunciado, de ahí el nombre de descenso de gradiente. Cuanto más pronunciada sea la pendiente, mayor será la magnitud del gradiente y, por lo tanto, mayor será el paso hacia el mínimo. Puede controlar el tamaño de cada paso escalando el gradiente según un factor denominado tasa de aprendizaje. A medida que se alcanza el punto más bajo, la pendiente disminuye a cero. Este punto más bajo de la ruta se produce en los valores óptimos theta1, theta2.
#
#
# ### Gradient descent
#
# Exploremos algunas características adicionales del descenso en gradiente.
#
# ![image-9.png](attachment:image-9.png)
#
# - El gradiente de la función de coste se calcula sobre todo el conjunto de datos de cada iteración.
#
# - Cuando el conjunto de datos es grande, el descenso del gradiente se vuelve muy lento.
#
# - Podrías intentar acelerar la convergencia aumentando la tasa de aprendizaje, pero la convergencia se vuelve menos probable, ya que los pasos pueden ser demasiado grandes para notar los mínimos.
#
# - En lugar de usar el todo, el gradiente de la función de costo se puede aproximar eligiendo un subconjunto aleatorio de los datos para calcularlo.
#
# ### Stochastic Gradient Descent
#
# Una variación del algoritmo de descenso de gradiente es el descenso de gradiente estocástico, o SGD.
#
#
# - Es más rápido, pero puede ser menos preciso.
#
# - Utiliza un subconjunto aleatorio de datos de entrenamiento y se escala bien.
#
# - Es más probable que el SGD pase por alto los mínimos locales y encuentre los mínimos globales de la función de costos.
#
# - Converge rápidamente hacia un mínimo global, pero puede eludirlo durante algún tiempo.
#
# ![image-10.png](attachment:image-10.png)
#
#
# La convergencia se puede mejorar si se ralentiza a medida que el algoritmo se acerca a un mínimo global.
#
# - Puedes concentrarte en lo mínimo disminuyendo la tasa de aprendizaje a medida que te acerques, o puedes aumentar gradualmente el tamaño de la muestra de datos aleatorios utilizada para calcular el gradiente de la función de costo.
#
# ### RECAP
#
# - el objetivo del entrenamiento en regresión logística es predecir las clases con un mínimo de error.
#
# - El proceso de capacitación consiste en pasos clave creados para encontrar un conjunto de parámetros, o theta, que minimicen la función de costo.
#
# - Se utiliza un paso de optimización para encontrar los mejores parámetros.
#
# - La métrica para optimizar la regresión logística es una función de costo denominada pérdida de registro, que debe minimizarse.
#
# - La pérdida de registros favorece las clasificaciones confiables que son correctas y penaliza las predicciones confiables e incorrectas.
#
# - El descenso de gradiente es un enfoque inteligente e iterativo para encontrar el mínimo de una función.
#
# - El descenso de gradiente estocástico es una variación escalable del algoritmo de descenso de gradiente, que utiliza un subconjunto aleatorio de datos de entrenamiento.
