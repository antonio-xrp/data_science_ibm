# %% [markdown]
# Regularization in Linear Regression
#
# - La regularización es una técnica de regresión para evitar el sobreajuste.
#
# - Limita el modelo durante el entrenamiento, lo que lo disuade de ajustarse demasiado a los datos de entrenamiento.
#
# - Suprime el tamaño de sus coeficientes.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Regresión lineal
#
# El objetivo es minimizar la función de pérdida, que normalmente se mide como el MSE entre los valores objetivo pronosticados y reales.
#
# - La ponderación se denominan comúnmente coeficientes del modelo de regresión lineal.
#
# ![image-3.png](attachment:image-3.png)
#
# Ridge & lasso regresion
#
# - Son formas regularizadas de regresión lineal que solo difieren en sus funciones de costo.
#
# - Ridge utiliza una penalización de L2 o de suma de cuadrados en sus coeficientes, lo que ayuda a reducirlos.
#
# - Laso utiliza una penalización de L1 o de suma de valores absolutos en sus coeficientes, esta penalización puede reducir algunos coeficientes a cero exactamente. Ademas, responde bien a la escacez de funciones, lo que he lace útilil para tareas de selección de funciones y comprensión de datos.
#
# ![image-4.png](attachment:image-4.png)
#
# sparse coefficientes, high SNR: Significa que solo una pequeña cantidad de variables contribuyen de manera significativa a un conjunto de datos, mientras que el resto tiene poco ningún impacto.
#
# ![image-5.png](attachment:image-5.png)
#
# Sparse coefficients, low SNR: La regresión lineal funciona muy mal en este caso, ya que tiende a sobreestimar en gran medida los coeficientes ideales, sobrepasar la mayoria de los coeficientes cero y asignar grandes coeficentes negativos cuando deberia de ser cero.
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# RECAP
