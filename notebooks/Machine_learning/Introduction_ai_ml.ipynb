# %% [markdown]
# ### INTRODUCTION TO ARTIFICIAL INTELLIGENCE AND MACHINE LEARNING
#
# > Un consejo que quiero que sepas de inmediato es que el Deep learning será un subconjunto del Machine learning, que a su vez será un subconjunto de la inteligencia artificial.
#
# - Explicaremos cómo el aprendizaje profundo ha superado muchas de las limitaciones de las técnicas clásicas de aprendizaje automático y nos ha ayudado a entrar en una nueva era de inteligencia artificial.
#
# - Ahora bien, llegar a esa era requirió muchos altibajos. Y hablaremos sobre la historia del auge y la caída de las inversiones y el entusiasmo en torno a la inteligencia artificial que, finalmente, condujeron al auge actual de la IA.
#
# - Con esto en mente, analizaremos cómo el estado actual de la inteligencia artificial y la trayectoria de los avances actuales se diferencian de los avances que vimos en la IA en el pasado.
#
# - A continuación, analizaremos algunos ejemplos de aplicaciones de la IA en el mundo real y , al final de este curso, deberías tener un conocimiento profundo de los principios subyacentes que ahora lo hacen posible.
#
# ### AI Breakthroughs
#
# Para comprender hasta qué punto nos ha llevado la inteligencia artificial en la historia reciente, dos de los mayores avances que seguiremos abordando a lo largo de la historia de la inteligencia artificial son **el procesamiento de imágenes y la traducción automática.**
#
# - Para entender la clasificación de las imágenes, imaginemos que se nos asigna la tarea de identificar cuál de estas imágenes es un perro y cuál de estas imágenes es un gato.
# Y si nos remontamos a 2015, los ordenadores han podido clasificar mejor esas imágenes en categorías que los humanos.
#
# - En el caso de la traducción automática, nuestro objetivo es tomar una frase u oración en un idioma, por ejemplo, si soy estudiante. Y luego traducir en otro idioma, teniendo en cuenta todas las complejidades del orden de las palabras y la redacción correcta de ese otro idioma, que tenemos aquí en francés. Y se está haciendo un trabajo increíble para que las máquinas puedan traducirlo en una interpretación casi humana.
#
# Ahora bien, estos son problemas muy difíciles para los modelos clásicos de aprendizaje automático.
#
# - En el caso de las imágenes, era difícil identificar características útiles.
#
# - Además, para el procesamiento del lenguaje natural, las traducciones, como ya hemos dicho, no son tan sencillas como ir palabra por palabra. Pero teniendo en cuenta el orden de las palabras, la redacción adecuada y el uso común en los diferentes idiomas.
#
# Los avances en el aprendizaje profundo, así como las innovaciones en el ámbito del almacenamiento y la potencia de procesamiento de datos, nos han permitido dar un paso adelante y empezar a tener esta capacidad para superar estos modelos de aprendizaje automático.
#
# ![image.png](attachment:image.png)
#
# ### AI IS THE NEW ELECTRICITY
#
# El posible impacto futuro de la IA son enormes.
#
# >La IA tendrá un impacto similar en todas las principales industrias, del mismo modo que lo tuvo la electricidad hace 100 años. Andrew Ng,
#
# uno de los líderes en el campo de la inteligencia artificial, trabajó en Stanford, fue cofundador de Coursera y actualmente dirige deeplearning.ai.
#
# Ademas,ha dado charlas discutiendo en profundidad la cita anterior que se puede encontrar en YouTube, y podemos pensar en los principales avances de las dos últimas diapositivas para señalar algunos de esos avances importantes.
#
# Pero también debemos pensar en el impacto que tiene la inteligencia artificial en la publicidad:
# - Con el marketing segmentado.
# - En las tiendas físicas con la optimización de la cadena de suministro
# - En los vehículos autónomos en el sector del transporte.
# - En los hogares inteligentes nos proporcionan entretenimiento y seguridad mediante comandos de voz.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Definitions
#
# > Deep learning es un subconjunto del Machine learning y el Machine learning , un subconjunto de la inteligencia artificial.
#
# - La inteligencia artificial es cualquier programa que puede detectar, razonar, actuar y adaptarse, básicamente, es una máquina que adopta cualquier forma de comportamiento inteligente.
#
# - Machine Learning es un subconjunto de ellos, en el que es capaz de replicar un comportamiento inteligente, pero la máquina aprenderá a medida que se le expongan más datos.
#
# - Deep Learning es un subconjunto del Machine Learning, lo que significa que también mejorará a medida que esté expuesto a más datos, pero ahora específicamente a aquellos algoritmos que tienen redes neuronales de varios niveles.
#
# ![image-3.png](attachment:image-3.png)
#
# ### Artificial Intelligence
#
# - El diccionario Merriam-Webster la define como una rama de la informática que se ocupa de la simulación del comportamiento inteligente en las computadoras. Muy similar a lo que acabamos de mencionar, cualquier medio de simular un comportamiento inteligente.
#
# - Wikipedia Coloquialmente, el término inteligencia artificial se aplica cuando una máquina imita las funciones cognitivas que los humanos asocian con otras mentes humanas, como el aprendizaje y la resolución de problemas.
#
# - Cuando utilizamos el término inteligencia artificial en nuestro día a día, vemos una definición muy similar a la que tenemos aquí y la idea de que la inteligencia se define como inteligencia humana.
#
# - Esto tiene sus raíces en la acuñación histórica del término inteligencia artificial y está relacionado con la cuestión de Turing, de la que hablaremos a medida que nos adentremos en la historia de la inteligencia artificial.
#
# - Solo para dejar claro cuál sería un ejemplo de inteligencia artificial que no se incluya necesariamente en nuestros subconjuntos de aprendizaje automático y aprendizaje profundo. Sería algo así como un sistema basado en reglas en el que no aprende a medida que ingresan más datos.
#
# ![image-4.png](attachment:image-4.png)
