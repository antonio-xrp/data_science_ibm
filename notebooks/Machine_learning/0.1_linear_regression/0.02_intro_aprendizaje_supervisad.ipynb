# %% [markdown]
# ### INTRODUCCIÓN AL APRENDIZAJE AUTOMÁTICO SUPERVISADO
#
# ### Fit parameters vs Hyperparameters
#
# Ahora vamos a aclarar esta diferencia entre parámetros e hiperparámetros.
#
# ![image.png](attachment:image.png)
#
# Nuestros parámetros de ajuste, implican aspectos del modelo que estimaremos utilizando los datos, como nuestros coeficientes de regresión lineal.
#
# Sin embargo, antes de ajustar nuestro modelo a nuestras X e Y, debemos tomar ciertas decisiones con respecto al modelo en sí , y estas decisiones serán las que determinarán la forma en que surjan los hiperparámetros.
#
# Esto nos permitirá modificar un modelo determinado de formas que el propio modelo no aprende directamente y, por lo general, estos ajustes nos ayudarán a optimizar la potencia de ese modelo.
#
# ### Machine Learning Frameweork
#
# Ahora bien, dentro del aprendizaje supervisado, habrá otra división común en dos categorías según la variable de resultado que intentemos predecir.
#
# ![image-2.png](attachment:image-2.png)
#
# - Por un lado, **tenemos la regresión**, y ahora la regresión no se refiere solo a la regresión lineal, sino que se refiere a cualquier momento en que intentemos **predecir un valor numérico**. Un ejemplo de esto sería crear modelos para predecir el precio de las acciones, los ingresos de taquilla o incluso una ubicación, suponiendo que estamos intentando predecir las coordenadas X e Y de esa ubicación.
#
# - **Clasificación**, y aquí es cuando nuestra variable de **resultado es categórica**. Así que, una vez más, ambas dependen de cuál sea la variable de resultado que intentemos predecir. Y en este ejemplo, incluiríamos cosas como el reconocimiento facial, en el que predecimos el rostro de una persona en particular que aparece en una imagen, nuestro ejemplo de pérdida de clientes, en el que predecimos si un cliente se va o no, y predecimos qué palabra aparecerá a continuación en una frase, como suele verse al iniciar una búsqueda en Google, cada una de ellas tiene un resultado categórico.
#
#
# Así que eso es regresión versus clasificación.
#
# ### How Does Machine Learning Work?
#
# **Y todo esto en lo que respecta al aprendizaje automático supervisado** puede incluirse en la ecuación que vemos aquí, que proporciona el marco de aprendizaje automático para todos los modelos de aprendizaje automático supervisado.
#
# ![image-3.png](attachment:image-3.png)
#
# Tenemos una entrada X, una salida de ys pronosticada dada una X concreta y algún modelo de aprendizaje automático que genera una predicción mediante el aprendizaje de los parámetros apropiados (Omega).
#
# **Entonces, ¿cuál es el proceso mediante el cual aprendemos los parámetros correctos?**
#
# ![image-4.png](attachment:image-4.png)
#
# - Los científicos de datos entrenarán el modelo para encontrar los mejores parámetros analizando los datos anteriores.
#
# - Cada observación X se relacionará con alguna variable de resultado y.
#
# - Cuantos más valores tengamos, mejor aprenderá el modelo de aprendizaje automático los parámetros que definen esta relación entre las características de X y las variables de resultado y.
#
# - Una vez que nos hayamos entrenado en nuestros datos anteriores, a medida que obtengamos nuevas observaciones, como nuevos clientes en nuestro ejemplo de abandono, podemos utilizar nuestra experiencia pasada para modelar la probabilidad de que estos nuevos clientes se pierdan.
#
# - Introducimos estos valores en nuestro modelo con los parámetros de aprendizaje de nuestro conjunto de entrenamiento para elaborar las predicciones YP.
#
# - Y tenemos una predicción para cada nuevo cliente.
#
# Ahora bien, en la práctica, no queremos formarnos con todos los clientes anteriores, ya que un modelo muy complejo puede seguir este patrón, por ejemplo, si un cliente ha sido miembro durante tres meses, tiene una suscripción de 30 dólares al mes y se llama Daniel Mandel, lo abandonará. Sería demasiado específico, pero un modelo complejo puede aprender algo tan específico.
#
# - Lo que nos gustaría hacer es tener algo que pueda generalizarse mejor cuando lleguen nuevos datos. Por lo tanto, entrenaríamos solo con un subconjunto de nuestros datos antiguos y optimizaríamos nuestros resultados con un conjunto de datos retenido que no se haya entrenado para ver su rendimiento en el mundo real antes de poner nuestro modelo en producción.
#
#
# **Entonces, ¿cuál es el mecanismo que impulsa la actualización de nuestros parámetros a medida que llegan nuevos datos?**
#
# ![image-5.png](attachment:image-5.png)
#
# Al final de estas viñetas, hemos introducido este nuevo término, el término de pérdida, y tenemos esta función J de Y e YP.
#
# - La mayoría de los modelos van a definir una puntuación cuantitativa para determinar qué tan buenas son nuestras predicciones y, si observamos esta función de pérdida, esta J de Y e YP, el resultado sería en realidad una medida cuantitativa de qué tan cerca está nuestra YP, nuestra predicción, de y, de los valores reales.
#
#
# ![image-6.png](attachment:image-6.png)
#
# Y teniendo en cuenta nuestras características X y la variable de resultado y, la regla de
# actualización determinará cómo actualizar nuestros parámetros.
#
# **Por lo general, intentará encontrar aquellos parámetros que minimicen esa función de pérdida. Minimice el error entre y y nuestra predicción* que proviene de F de nuestros parámetros y nuestra entrada.**
#
#
# Con esto terminamos nuestra introducción al aprendizaje automático supervisado. En la siguiente sección, abordaremos diferentes enfoques del aprendizaje automático supervisado, es decir, diferenciaremos si nuestros objetivos son centrarnos en la interpretación o en la predicción. Gracias.
